# %%
# ============================================================
# Cell 0 — CONFIG, FOLDERS, LOGGING
# ------------------------------------------------------------
# - Train set:   images/problem/{task1, task2}
# - Public test: images/test  (PNG trộn cả 2 task)
# - Private:     ./private_test (ở root; có thể bị khoá)
# - Sau TRAIN: đóng băng (freeze) tham số -> INFER không học nữa.
# ============================================================

import os, sys, glob, time, math, json, logging, zipfile, heapq, itertools, random
from collections import defaultdict
import numpy as np
import pandas as pd
import cv2
from tqdm import tqdm

def ensure_dir(path: str) -> bool:
    """Tạo thư mục nếu chưa có; trả False nếu tạo thất bại (đã log ra stdout)."""
    try:
        os.makedirs(path, exist_ok=True)
        return True
    except Exception as e:
        print(f"[ERROR] Cannot create dir {path}: {e}", flush=True)
        return False

def require_dir(path: str, create: bool = False) -> str:
    """
    Đảm bảo thư mục tồn tại; nếu create=True thì cố gắng tạo, không được thì ném lỗi.
    Dùng cho INPUT (create=False) & OUTPUT (create=True).
    """
    if os.path.isdir(path):
        return path
    if create and ensure_dir(path):
        return path
    raise FileNotFoundError(f"Required directory not found: {path}")

# ---- Base path (nếu notebook nằm trong code/ thì lùi 1 cấp) ----
CWD = os.getcwd()
BASE_DIR = os.path.abspath(os.path.join(CWD, "..")) if os.path.basename(CWD) == "code" else os.path.abspath(CWD)

# ---- TRAIN SET (images/problem) ----
IMAGES_DIR      = os.path.join(BASE_DIR, "images")
TRAIN_TASK1_DIR = require_dir(os.path.join(IMAGES_DIR, "problem", "task1"), create=True)   # có thể rỗng
TRAIN_TASK2_DIR = require_dir(os.path.join(IMAGES_DIR, "problem", "task2"), create=True)   # có thể rỗng

# ---- TEST SET ----
TEST_PUBLIC_DIR  = require_dir(os.path.join(IMAGES_DIR, "test"), create=True)              # public_test
PRIVATE_TEST_DIR = os.path.join(BASE_DIR, "private_test")                                  # có thể chưa mở khoá

# ---- OUTPUT & SOLVED ----
SLOVED_TASK1   = require_dir(os.path.join(IMAGES_DIR, "sloved", "task1"), create=True)     # giữ nguyên "sloved"
SLOVED_TASK2   = require_dir(os.path.join(IMAGES_DIR, "sloved", "task2"), create=True)
SLOVED_PUBLIC  = require_dir(os.path.join(IMAGES_DIR, "sloved", "public_test"), create=True)
SLOVED_PRIVATE = require_dir(os.path.join(IMAGES_DIR, "sloved", "private_test"), create=True)
OUTPUT_DIR     = require_dir(os.path.join(BASE_DIR, "output"), create=True)

# ---- ĐẶC TẢ đề bài ----
GRID_R, GRID_C = 3, 5
H, W           = 360, 600
TILE_H, TILE_W = H // GRID_R, W // GRID_C   # 120 x 120
N_TILES        = GRID_R * GRID_C            # 15

# ---- Trọng số tín hiệu (khởi tạo; sẽ học ONLINE trong TRAIN) ----
W_INIT = {
    "alpha": 1.00,   # Lab color MSE
    "beta":  0.35,   # gradient MSE
    "gamma": 0.80,   # 1 - SSIM
    "ori":   0.10,   # HOG chi2
    "lbp":   0.10,   # LBP chi2
    "prior_w": 0.10  # trọng số location prior theo hàng (trên/giữa/dưới)
}
W_BOUNDS = {
    "alpha": (0.0, 2.0),
    "beta":  (0.0, 1.5),
    "gamma": (0.0, 1.5),
    "ori":   (0.0, 1.0),
    "lbp":   (0.0, 1.0),
    "prior_w": (0.0, 0.4),
}

# ---- Fine-tune per-image (TRAIN ONLY) — grid nhỏ để không chạy quá lâu ----
TUNE_BAND    = [5, 6]                     # dải biên khi so khớp cạnh
TUNE_PRIOR_W = [0.00, 0.10]               # quét nhẹ prior_w
TUNE_DW = {                               
    # Quét nhẹ quanh trọng số hiện tại (alpha giữ nguyên cho ổn định)
    "alpha": [0.0],
    "beta":  [-0.05, 0.0, +0.05],
    "gamma": [-0.10, 0.0, +0.10],
    "ori":   [0.0, +0.05],
    "lbp":   [0.0, +0.05],
}

# ---- Online learning (TRAIN ONLY) — unsupervised metric learning ----
LEARN_CFG = {
    "negatives_per_pos": 2,   # số negative cho mỗi positive edge
    "margin": 0.06,           # biên hinge (mức "gắt")
    "lr": 0.04,               # learning rate
    "ema": 0.85,              # làm mượt tham số (ổn định)
    "max_pairs_per_image": 40,# trần số cặp train/ảnh
    "band_for_learning": 6    # band dùng khi trích feature cho học
}

# ---- Auto-budget mặc định (2h); bạn có presets 1h/2h/3h ở cuối Cell ----
TOTAL_TRAIN_IMAGES = 0
try:
    TOTAL_TRAIN_IMAGES = len(glob.glob(os.path.join(TRAIN_TASK1_DIR, "*.png"))) \
                       + len(glob.glob(os.path.join(TRAIN_TASK2_DIR, "*.png")))
except Exception:
    TOTAL_TRAIN_IMAGES = 0
TOTAL_TRAIN_IMAGES         = max(TOTAL_TRAIN_IMAGES, 1)  # tránh chia 0
TOTAL_TRAIN_SECONDS        = 2 * 3600                     # mặc định 2 giờ
PER_IMAGE_BUDGET_SEC       = int(max(20, min(80, (TOTAL_TRAIN_SECONDS*0.85)/TOTAL_TRAIN_IMAGES)))
_EST_TRIAL_SEC             = 3.5                          # ước lượng 1 trial
MAX_PARAM_TRIALS_PER_IMAGE = int(max(6, min(14, PER_IMAGE_BUDGET_SEC/_EST_TRIAL_SEC)))
TIME_BUDGET_PER_IMAGE_SEC  = int(PER_IMAGE_BUDGET_SEC)

# ---- File IO ----
PUBLIC_CSV   = os.path.join(OUTPUT_DIR, "public_output.csv")
PRIVATE_CSV  = os.path.join(OUTPUT_DIR, "private_output.csv")
MODEL_PATH   = os.path.join(OUTPUT_DIR, "trained_model.json")
RUN_LOG      = os.path.join(OUTPUT_DIR, "run.log")
SUBMISSION   = os.path.join(OUTPUT_DIR, "submission.zip")

# Optional hints CSV cho Task1 (nếu có)
HINTS_TRAIN1 = os.path.join(OUTPUT_DIR, "task1_hints.csv")
HINTS_PUBLIC = os.path.join(OUTPUT_DIR, "public_task1_hints.csv")
HINTS_PRIVATE= os.path.join(OUTPUT_DIR, "private_task1_hints.csv")

# ---- Reproducibility ----
random.seed(42)
np.random.seed(42)

# ---- Logger (file + stdout) ----
for h in list(logging.root.handlers):
    logging.root.removeHandler(h)
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    handlers=[logging.FileHandler(RUN_LOG, mode="w", encoding="utf-8"),
              logging.StreamHandler(sys.stdout)]
)
logger = logging.getLogger("VOAI2025_Task2")
logger.info(f"BASE_DIR = {BASE_DIR}")
logger.info("Folders ready. Logging initialized.")
logger.info(f"[DEFAULT BUDGET] train_imgs={TOTAL_TRAIN_IMAGES} | per_image={PER_IMAGE_BUDGET_SEC}s "
            f"| max_trials={MAX_PARAM_TRIALS_PER_IMAGE} | learn_cfg={LEARN_CFG}")

# ============================================================
# ⏱️ TIME PRESETS (1h/2h/3h) — dễ chỉnh thời lượng TRAIN
#  Cách dùng: đổi TRAIN_PRESET thành "1h" | "2h" | "3h"
# ============================================================
TRAIN_PRESET = "2h"  # ← đổi ở đây nếu muốn 1h/3h nhanh chóng

PRESET_CONFIGS = {
    "1h": {
        "TUNE_BAND": [6],
        "TUNE_PRIOR_W": [0.10],
        "TUNE_DW": {"alpha":[0.0],"beta":[-0.05,0.0,0.05],"gamma":[-0.10,0.0,0.10],"ori":[0.0],"lbp":[0.0]},
        "NEG": 2, "MAX_PAIRS": 30, "EMA": 0.85,
        "EST_TRIAL_SEC": 3.5, "TRIALS_RANGE": (6,10), "PER_IMAGE_CAP": (18,35),
        "TOTAL_TRAIN_SECONDS": 1*3600,
    },
    "2h": {
        "TUNE_BAND": [5,6],
        "TUNE_PRIOR_W": [0.00,0.10],
        "TUNE_DW": {"alpha":[0.0],"beta":[-0.05,0.0,0.05],"gamma":[-0.10,0.0,0.10],"ori":[0.0,0.05],"lbp":[0.0,0.05]},
        "NEG": 2, "MAX_PAIRS": 40, "EMA": 0.85,
        "EST_TRIAL_SEC": 3.5, "TRIALS_RANGE": (8,14), "PER_IMAGE_CAP": (35,70),
        "TOTAL_TRAIN_SECONDS": 2*3600,
    },
    "3h": {
        "TUNE_BAND": [5,6,7],
        "TUNE_PRIOR_W": [0.00,0.05,0.10,0.15],
        "TUNE_DW": {"alpha":[0.0],"beta":[-0.10,-0.05,0.0,0.05,0.10],"gamma":[-0.15,-0.10,0.0,0.10,0.15],"ori":[0.0,0.05],"lbp":[0.0,0.05]},
        "NEG": 3, "MAX_PAIRS": 60, "EMA": 0.80,
        "EST_TRIAL_SEC": 3.2, "TRIALS_RANGE": (10,18), "PER_IMAGE_CAP": (60,95),
        "TOTAL_TRAIN_SECONDS": 3*3600,
    },
}

def _apply_time_preset(preset):
    """Áp cấu hình thời gian train (1h/2h/3h) một cách an toàn."""
    global TUNE_BAND, TUNE_PRIOR_W, TUNE_DW
    global LEARN_CFG, MAX_PARAM_TRIALS_PER_IMAGE, TIME_BUDGET_PER_IMAGE_SEC
    global TOTAL_TRAIN_SECONDS, PER_IMAGE_BUDGET_SEC, _EST_TRIAL_SEC

    if preset not in PRESET_CONFIGS:
        print(f"[WARN] Unknown preset: {preset}. Keep defaults.")
        return

    cfg = PRESET_CONFIGS[preset]
    TUNE_BAND, TUNE_PRIOR_W, TUNE_DW = cfg["TUNE_BAND"], cfg["TUNE_PRIOR_W"], cfg["TUNE_DW"]
    LEARN_CFG["negatives_per_pos"]   = cfg["NEG"]
    LEARN_CFG["max_pairs_per_image"] = cfg["MAX_PAIRS"]
    LEARN_CFG["ema"]                 = cfg["EMA"]

    TOTAL_TRAIN_SECONDS = cfg["TOTAL_TRAIN_SECONDS"]
    _EST_TRIAL_SEC      = cfg["EST_TRIAL_SEC"]

    # Tự ước lượng ngân sách/ảnh theo số ảnh train (dành ~85% cho solve+tuning)
    total_imgs = 0
    try:
        total_imgs = len(glob.glob(os.path.join(TRAIN_TASK1_DIR, "*.png"))) \
                   + len(glob.glob(os.path.join(TRAIN_TASK2_DIR, "*.png")))
    except Exception:
        total_imgs = 0
    total_imgs = max(total_imgs, 1)

    raw_budget = (TOTAL_TRAIN_SECONDS * 0.85) / total_imgs
    lo, hi     = cfg["PER_IMAGE_CAP"]
    PER_IMAGE_BUDGET_SEC = int(max(lo, min(hi, raw_budget)))
    lo_t, hi_t = cfg["TRIALS_RANGE"]
    MAX_PARAM_TRIALS_PER_IMAGE = int(max(lo_t, min(hi_t, PER_IMAGE_BUDGET_SEC / _EST_TRIAL_SEC)))
    TIME_BUDGET_PER_IMAGE_SEC  = int(PER_IMAGE_BUDGET_SEC)

    print(f"[PRESET] {preset} | train_imgs={total_imgs} | per_image={PER_IMAGE_BUDGET_SEC}s | "
          f"max_trials={MAX_PARAM_TRIALS_PER_IMAGE} | learn_cfg={LEARN_CFG}")

_apply_time_preset(TRAIN_PRESET)
print("✅ Cell 0 ready.")
# Out:
# 2025-10-29 04:54:55,477 | INFO | BASE_DIR = /home/dammanhdungvn/learn_ml/project
# 2025-10-29 04:54:55,478 | INFO | Folders ready. Logging initialized.
# 2025-10-29 04:54:55,479 | INFO | [DEFAULT BUDGET] train_imgs=16 | per_image=80s | max_trials=14 | learn_cfg={'negatives_per_pos': 2, 'margin': 0.06, 'lr': 0.04, 'ema': 0.85, 'max_pairs_per_image': 40, 'band_for_learning': 6}
# [PRESET] 2h | train_imgs=16 | per_image=70s | max_trials=14 | learn_cfg={'negatives_per_pos': 2, 'margin': 0.06, 'lr': 0.04, 'ema': 0.85, 'max_pairs_per_image': 40, 'band_for_learning': 6}
# ✅ Cell 0 ready.

# %%
# ============================================================
# Cell 1 — IO HELPERS
# ------------------------------------------------------------
# - list_images: chỉ liệt kê *.png (đúng đề bài).
# - load_image_rgb: đọc RGB + assert đúng 600x360.
# - load_hints_csv: nếu có file hint cho Task1 (0,0).
# ============================================================

def list_images(folder, exts=(".png",)):
    try:
        files = [p for p in glob.glob(os.path.join(folder, "*")) if p.lower().endswith(exts)]
        files.sort()
        return files
    except Exception as e:
        logger.error(f"Cannot list images in {folder}: {e}")
        return []

def load_image_rgb(path):
    bgr = cv2.imread(path, cv2.IMREAD_COLOR)
    if bgr is None:
        raise FileNotFoundError(f"Cannot read image: {path}")
    h, w = bgr.shape[:2]
    if (h, w) != (H, W):
        raise AssertionError(f"Image must be {H}x{W}, got {(h,w)} @ {os.path.basename(path)}")
    return cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)

def load_hints_csv(path):
    """
    CSV (optional): image_filename, top_left_piece_index
    Dùng cho Task1 nếu bạn có chỉ số mảnh (0,0).
    """
    if not os.path.isfile(path):
        logger.warning(f"Hint file not found (optional): {path}")
        return {}
    try:
        df = pd.read_csv(path)
        mp = {str(row["image_filename"]).strip(): int(row["top_left_piece_index"]) for _, row in df.iterrows()}
        logger.info(f"Loaded {len(mp)} hints from {path}.")
        return mp
    except Exception as e:
        logger.error(f"Failed to read hints CSV {path}: {e}")
        return {}

print("✅ Cell 1 ready.")
# Out:
# ✅ Cell 1 ready.

# %%
# ============================================================
# Cell 2 — TILING & ASSEMBLE
# ------------------------------------------------------------
# - Tách ảnh xáo trộn thành 15 mảnh (row-major).
# - Lắp lại theo hoán vị (perm) cho visualization & export.
# ============================================================

def tiles_from_shuffled(rgb):
    tiles = []
    for r in range(GRID_R):
        for c in range(GRID_C):
            y0, y1 = r*TILE_H, (r+1)*TILE_H
            x0, x1 = c*TILE_W, (c+1)*TILE_W
            tiles.append(rgb[y0:y1, x0:x1].copy())
    return tiles  # list len=15

def assemble_by_perm(tiles, perm):
    canvas = np.zeros((H, W, 3), dtype=np.uint8)
    k = 0
    for r in range(GRID_R):
        for c in range(GRID_C):
            y0, y1 = r*TILE_H, (r+1)*TILE_H
            x0, x1 = c*TILE_W, (c+1)*TILE_W
            canvas[y0:y1, x0:x1] = tiles[perm[k]]
            k += 1
    return canvas

print("✅ Cell 2 ready.")
# Out:
# ✅ Cell 2 ready.

# %%
# ============================================================
# Cell 3 — EDGE FEATURES (5 cues)
# ------------------------------------------------------------
# Tín hiệu cho cạnh i->j theo hướng d ∈ {L,R,U,D}:
#   f = [ MSE_Lab, MSE_grad, (1-SSIM_L), HOG_chi2, LBP_chi2 ]
# Cost cạnh = w · f  (w học online ở TRAIN)
# ============================================================

from skimage.color import rgb2lab
from skimage.metrics import structural_similarity as ssim
from skimage.feature import local_binary_pattern

DIRS = ['L','R','U','D']
OPP  = {'L':'R','R':'L','U':'D','D':'U'}

def _lab01(tile_u8):
    return rgb2lab(tile_u8.astype(np.float32)/255.0)

def _band(img, side, band):
    if side == 'L': return img[:, :band, :]
    if side == 'R': return img[:, -band:, :]
    if side == 'U': return img[:band, :, :]
    if side == 'D': return img[-band:, :, :]
    raise ValueError(side)

def _grad_x(img):
    gx = img[:,1:,:] - img[:,:-1,:]
    gx = np.pad(gx, ((0,0),(0,1),(0,0)), mode='edge')
    return gx

def _grad_y(img):
    gy = img[1:,:,:] - img[:-1,:,:]
    gy = np.pad(gy, ((0,1),(0,0),(0,0)), mode='edge')
    return gy

def _normalize_band(arr):
    mu = arr.mean(axis=(0,1), keepdims=True)
    sd = arr.std(axis=(0,1), keepdims=True) + 1e-6
    return (arr - mu)/sd

def _ori_hist(lab, side, band, nbins=9):
    # HOG đơn giản từ kênh L
    gx = _grad_x(lab)[...,0]
    gy = _grad_y(lab)[...,0]
    mag = np.sqrt(gx**2 + gy**2)
    ori = np.arctan2(np.abs(gy), np.abs(gx))  # 0..pi/2

    def band2(arr):
        if side=='L': return arr[:, :band]
        if side=='R': return arr[:, -band:]
        if side=='U': return arr[:band, :]
        if side=='D': return arr[-band:, :]
    mag_b = band2(mag); ori_b = band2(ori)

    hist, _ = np.histogram(ori_b, bins=nbins, range=(0, np.pi/2), weights=mag_b)
    hist = hist.astype(np.float32); hist /= (hist.sum() + 1e-6)
    return hist

def _lbp_hist(lab, side, band, P=8, R=1.0):
    L = lab[...,0]
    lbp = local_binary_pattern(L, P=P, R=R, method='uniform')
    n_bins = P + 2

    def band2(arr):
        if side=='L': return arr[:, :band]
        if side=='R': return arr[:, -band:]
        if side=='U': return arr[:band, :]
        if side=='D': return arr[-band:, :]
    lbp_b = band2(lbp)

    hist, _ = np.histogram(lbp_b, bins=np.arange(0, n_bins+1), range=(0, n_bins))
    hist = hist.astype(np.float32); hist /= (hist.sum() + 1e-6)
    return hist

def _chi2(p, q):
    return 0.5 * np.sum(((p - q)**2) / (p + q + 1e-8))

def precompute_feats(tiles):
    """Tiền tính Lab & gradient cho từng mảnh (tăng tốc khi so khớp)."""
    feats = []
    for t in tiles:
        lab = _lab01(t)
        gx  = _grad_x(lab)
        gy  = _grad_y(lab)
        feats.append((lab, gx, gy))
    return feats

def edge_feature_vec(fA, fB, direction, band):
    """Trả về vector 5-dim f cho cạnh fA->fB theo hướng 'direction'."""
    labA, gxA, gyA = fA
    labB, gxB, gyB = fB

    if direction == 'R':
        a_c, b_c = _band(labA,'R',band), _band(labB,'L',band)
        a_gx, b_gx = gxA[:, -band:, :], gxB[:, :band, :]
        a_gy, b_gy = gyA[:, -band:, :], gyB[:, :band, :]
    elif direction == 'L':
        a_c, b_c = _band(labA,'L',band), _band(labB,'R',band)
        a_gx, b_gx = gxA[:, :band, :],  gxB[:, -band:, :]
        a_gy, b_gy = gyA[:, :band, :],  gyB[:, -band:, :]
    elif direction == 'D':
        a_c, b_c = _band(labA,'D',band), _band(labB,'U',band)
        a_gx, b_gx = gxA[-band:, :, :], gxB[:band, :, :]
        a_gy, b_gy = gyA[-band:, :, :], gyB[:band, :, :]
    else:  # 'U'
        a_c, b_c = _band(labA,'U',band), _band(labB,'D',band)
        a_gx, b_gx = gxA[:band, :, :],  gxB[-band:, :, :]
        a_gy, b_gy = gyA[:band, :, :],  gyB[-band:, :, :]

    # 1) MSE màu (Lab)
    a_c_n, b_c_n = _normalize_band(a_c), _normalize_band(b_c)
    mse_c = float(np.mean((a_c_n - b_c_n)**2))

    # 2) MSE gradient (năng lượng)
    a_g = np.sqrt(a_gx**2 + a_gy**2)
    b_g = np.sqrt(b_gx**2 + b_gy**2)
    a_g_n, b_g_n = _normalize_band(a_g), _normalize_band(b_g)
    mse_g = float(np.mean((a_g_n - b_g_n)**2))

    # 3) (1 - SSIM) trên kênh L
    a_l = a_c[...,0]; b_l = b_c[...,0]
    a_l_n = (a_l - a_l.mean())/(a_l.std()+1e-6)
    b_l_n = (b_l - b_l.mean())/(b_l.std()+1e-6)
    try:
        ssim_val = ssim(a_l_n, b_l_n, data_range=(a_l_n.max()-a_l_n.min()))
    except Exception:
        ssim_val = 0.0
    cost_ssim = 1.0 - float(ssim_val)

    # 4) HOG chi2, 5) LBP chi2
    sideA = {'R':'R','L':'L','D':'D','U':'U'}[direction]
    sideB = {'R':'L','L':'R','D':'U','U':'D'}[direction]
    chi2_ori = _chi2(_ori_hist(labA, sideA, band), _ori_hist(labB, sideB, band))
    chi2_lbp = _chi2(_lbp_hist(labA, sideA, band), _lbp_hist(labB, sideB, band))

    return np.array([mse_c, mse_g, cost_ssim, chi2_ori, chi2_lbp], dtype=np.float32)

print("✅ Cell 3 ready.")
# Out:
# ✅ Cell 3 ready.

# %%
# ============================================================
# Cell 4 — COST & MATRICES
# ------------------------------------------------------------
# - dot_cost: cost cạnh từ feat 5-dim và trọng số w.
# - precompute_costs_and_orders: ma trận cost & danh sách gợi ý theo từng hướng.
# ============================================================

def dot_cost(feat5, w):
    return (w["alpha"]*feat5[0] +
            w["beta"] *feat5[1] +
            w["gamma"]*feat5[2] +
            w["ori"]  *feat5[3] +
            w["lbp"]  *feat5[4])

def precompute_costs_and_orders(feats, band, w):
    n = len(feats)
    costs = {d: np.full((n, n), np.inf, dtype=np.float32) for d in DIRS}
    for i in range(n):
        for j in range(n):
            if i == j:
                continue
            for d in DIRS:
                f5 = edge_feature_vec(feats[i], feats[j], d, band)
                costs[d][i, j] = dot_cost(f5, w)
    # Mỗi (i,d) có list các j theo thứ tự cost tăng dần (loại i)
    orders = {d: [] for d in DIRS}
    for d in DIRS:
        for i in range(n):
            idx = np.argsort(costs[d][i, :]).tolist()
            orders[d].append([k for k in idx if k != i])
    return costs, orders

print("✅ Cell 4 ready.")
# Out:
# ✅ Cell 4 ready.

# %%
# ============================================================
# Cell 5 — LOCATION PRIOR (mềm theo hàng ảnh)
# ------------------------------------------------------------
# Ưu tiên hàng 0 (trên): b trung bình nhỏ; hàng 2 (dưới): b lớn hơn.
# Trả ma trận prior[piece, position], dùng như 1 thành phần cost mềm.
# ============================================================

from skimage.color import rgb2lab

def compute_location_prior(tiles):
    n = len(tiles)
    pri = np.zeros((n, GRID_R*GRID_C), dtype=np.float32)
    labs = [rgb2lab(t.astype(np.float32)/255.0) for t in tiles]
    means = [(L[...,0].mean(), L[...,1].mean(), L[...,2].mean()) for L in labs]  # (L,a,b)

    targets_b = [-5.0,  5.0, 20.0]  # row 0→1→2
    targets_a = [ 0.0,  0.0, -5.0]

    for p, (L, a, b) in enumerate(means):
        for pos in range(GRID_R*GRID_C):
            r = pos // GRID_C
            tb, ta = targets_b[r], targets_a[r]
            pri[p, pos] = ((b - tb)/20.0)**2 + 0.5*((a - ta)/15.0)**2
    return pri

print("✅ Cell 5 ready.")
# Out:
# ✅ Cell 5 ready.

# %%
# ============================================================
# Cell 6 — HEURISTIC + A*
# ------------------------------------------------------------
# f = g + h với h là lower bound:
# - Tổng biên mở (R/D) còn lại.
# - Min prior cho các vị trí chưa đặt.
# ============================================================

def right_index(idx):
    r, c = divmod(idx, GRID_C)
    return idx + 1 if c + 1 < GRID_C else None

def down_index(idx):
    r, c = divmod(idx, GRID_C)
    return idx + GRID_C if r + 1 < GRID_R else None

def min_unused_for(i, d, costs, orders, used_mask):
    """Chi phí thấp nhất i->j theo hướng d với j chưa dùng."""
    for j in orders[d][i]:
        if not ((used_mask >> j) & 1):
            return float(costs[d][i, j])
    return 0.0

def heuristic_with_prior(placement, used_mask, costs, orders, prior, prior_w):
    t = len(placement); h = 0.0
    # LB cho các cạnh mở
    for i in range(t):
        p = placement[i]
        jR = right_index(i)
        if jR is not None and jR >= t:
            h += min_unused_for(p, 'R', costs, orders, used_mask)
        jD = down_index(i)
        if jD is not None and jD >= t:
            h += min_unused_for(p, 'D', costs, orders, used_mask)
    # LB cho prior các vị trí trống
    remaining = list(range(t, GRID_R*GRID_C))
    unused   = [j for j in range(prior.shape[0]) if not ((used_mask >> j) & 1)]
    for pos in remaining:
        if not unused: break
        minp = min(prior[j, pos] for j in unused)
        h += prior_w * minp
    return h

def solve_astar_with_prior(tiles, costs, orders, prior, prior_w, initial_piece=None, log_prefix=""):
    n = len(tiles)
    frontier = []
    best_g = {}  # (idx, used_mask) -> best g đã gặp

    def push_state(placement, used_mask, g):
        h = heuristic_with_prior(placement, used_mask, costs, orders, prior, prior_w)
        heapq.heappush(frontier, (g+h, g, placement, used_mask))

    # Seed (Task1 có hint; Task2 thì thử mọi mảnh làm (0,0))
    if initial_piece is not None:
        used = (1 << initial_piece)
        placement = [initial_piece]
        g0 = prior_w * prior[initial_piece, 0]
        push_state(placement, used, g0)
        best_g[(1, used)] = g0
    else:
        for p in range(n):
            used = (1 << p)
            placement = [p]
            g0 = prior_w * prior[p, 0]
            push_state(placement, used, g0)
            best_g[(1, used)] = g0

    expansions = 0
    while frontier:
        f, g, placement, used = heapq.heappop(frontier)
        idx = len(placement)
        if idx == n:
            logger.info(f"{log_prefix}A* done | expansions={expansions} | best_cost={g:.6f}")
            return placement, g

        if best_g.get((idx, used), float('inf')) < g - 1e-12:
            continue

        r, c = divmod(idx, GRID_C)
        left_idx = idx - 1 if c - 1 >= 0 else None
        up_idx   = idx - GRID_C if r - 1 >= 0 else None

        # Ứng viên ưu tiên theo cost cục bộ + prior vị trí
        candidates = [p for p in range(n) if not ((used >> p) & 1)]
        def local_inc(p):
            inc = 0.0
            if left_idx is not None: inc += float(costs['R'][placement[left_idx], p])
            if up_idx   is not None: inc += float(costs['D'][placement[up_idx], p])
            inc += prior_w * prior[p, idx]
            return inc
        candidates.sort(key=local_inc)

        for p in candidates:
            add = 0.0
            if left_idx is not None: add += float(costs['R'][placement[left_idx], p])
            if up_idx   is not None: add += float(costs['D'][placement[up_idx], p])
            add += prior_w * prior[p, idx]

            used_new = used | (1 << p)
            placement_new = placement + [p]
            g_new = g + add
            key = (idx + 1, used_new)

            if g_new + 1e-12 < best_g.get(key, float('inf')):
                best_g[key] = g_new
                push_state(placement_new, used_new, g_new)

        expansions += 1
        if expansions % 5000 == 0:
            logger.info(f"{log_prefix}expansions={expansions}, frontier={len(frontier)}")

    raise RuntimeError(f"{log_prefix}No solution found.")

print("✅ Cell 6 ready.")
# Out:
# ✅ Cell 6 ready.

# %%
# ============================================================
# Cell 7 — OBJECTIVE & 2-OPT LOCAL REPAIR
# ------------------------------------------------------------
# Sau A*, thử hoán đổi cặp mảnh (2-opt) để hạ cost thêm chút
# (chữa lỗi nhỏ do heuristic không hoàn hảo).
# ============================================================

def right_neighbor_index(pos):
    r, c = divmod(pos, GRID_C)
    return pos + 1 if c + 1 < GRID_C else None

def down_neighbor_index(pos):
    r, c = divmod(pos, GRID_C)
    return pos + GRID_C if r + 1 < GRID_R else None

def total_cost_for_perm(perm, costs, prior, prior_w):
    tot = 0.0
    for pos, piece in enumerate(perm):
        rn = right_neighbor_index(pos)
        dn = down_neighbor_index(pos)
        if rn is not None:
            tot += float(costs['R'][piece, perm[rn]])
        if dn is not None:
            tot += float(costs['D'][piece, perm[dn]])
        tot += prior_w * prior[piece, pos]
    return float(tot)

def local_improve_2opt(perm, costs, prior, prior_w, max_iters=200, patience=40):
    best = perm[:]
    best_cost = total_cost_for_perm(best, costs, prior, prior_w)
    no_improve = 0
    n = len(perm)

    while no_improve < patience and max_iters > 0:
        improved = False
        for i in range(n-1):
            for j in range(i+1, n):
                cand = best[:]
                cand[i], cand[j] = cand[j], cand[i]
                c = total_cost_for_perm(cand, costs, prior, prior_w)
                if c + 1e-9 < best_cost:
                    best, best_cost = cand, c
                    improved = True
                    break
            if improved: break
        no_improve = 0 if improved else (no_improve + 1)
        max_iters -= 1
    return best, best_cost

print("✅ Cell 7 ready.")
# Out:
# ✅ Cell 7 ready.

# %%
# ============================================================
# Cell 8 — SOLVE ONE IMAGE WITH (w, band, prior_w)
# ------------------------------------------------------------
# - Tách mảnh → tiền tính đặc trưng → cost ma trận → A* → 2-opt.
# - Trả perm, cost, ảnh ghép & các cache (tiles, feats, costs, prior).
# ============================================================

def solve_one_image_with_params(path, w, band, prior_w, initial_piece=None, do_local_improve=True):
    rgb = load_image_rgb(path)
    tiles = tiles_from_shuffled(rgb)
    feats = precompute_feats(tiles)
    costs, orders = precompute_costs_and_orders(feats, band, w)
    prior = compute_location_prior(tiles)

    perm, best_cost = solve_astar_with_prior(
        tiles, costs, orders, prior,
        prior_w=prior_w,
        initial_piece=initial_piece,
        log_prefix=f"{os.path.basename(path)} | "
    )
    if do_local_improve:
        perm, best_cost = local_improve_2opt(perm, costs, prior, prior_w, max_iters=120, patience=30)
    vis = assemble_by_perm(tiles, perm)
    return perm, best_cost, vis, tiles, feats, costs, prior

print("✅ Cell 8 ready.")
# Out:
# ✅ Cell 8 ready.

# %%
# ============================================================
# Cell 9 — AUTO FINE-TUNING (TRAIN ONLY)
# ------------------------------------------------------------
# Sinh tập tham số (w, band, prior_w) quanh w hiện tại, thử có
# giới hạn thời gian/lượt, chọn cấu hình tốt nhất cho từng ảnh.
# ============================================================

def clip_weight(name, val):
    lo, hi = W_BOUNDS[name]
    return float(np.clip(val, lo, hi))

def generate_param_candidates(w_base):
    """Sinh danh sách (w, band, prior_w) quanh w_base theo TUNE_*."""
    cands = []
    for band in TUNE_BAND:
        for pw in TUNE_PRIOR_W:
            for db in TUNE_DW["beta"]:
                for dg in TUNE_DW["gamma"]:
                    for do in TUNE_DW["ori"]:
                        for dl in TUNE_DW["lbp"]:
                            w = dict(w_base)
                            w["beta"]  = clip_weight("beta",  w["beta"]  + db)
                            w["gamma"] = clip_weight("gamma", w["gamma"] + dg)
                            w["ori"]   = clip_weight("ori",   w["ori"]   + do)
                            w["lbp"]   = clip_weight("lbp",   w["lbp"]   + dl)
                            cands.append( (w, band, clip_weight("prior_w", pw)) )
    random.Random(0).shuffle(cands)
    return cands

def choose_best_for_image_with_tuning(path, w_base, initial_piece=None):
    """Chọn cấu hình tốt nhất cho 1 ảnh (theo cost) trong ngân sách cho phép."""
    param_sets = generate_param_candidates(w_base)
    best = {"perm": None, "cost": float("inf"), "w": None, "band": None, "prior_w": None, "vis": None,
            "tiles": None, "feats": None, "costs": None, "prior": None}
    start = time.time()
    trials = 0

    for (w, band, pw) in param_sets:
        if trials >= MAX_PARAM_TRIALS_PER_IMAGE:
            logger.info(f"{os.path.basename(path)} | stop by trial cap: {trials}")
            break
        if time.time() - start > TIME_BUDGET_PER_IMAGE_SEC:
            logger.info(f"{os.path.basename(path)} | stop by time budget: {TIME_BUDGET_PER_IMAGE_SEC}s")
            break
        try:
            perm, cost, vis, tiles, feats, costs, prior = solve_one_image_with_params(
                path, w, band, pw, initial_piece=initial_piece, do_local_improve=True
            )
            trials += 1
            if cost < best["cost"]:
                best.update({"perm":perm,"cost":cost,"w":w,"band":band,"prior_w":pw,"vis":vis,
                             "tiles":tiles,"feats":feats,"costs":costs,"prior":prior})
        except Exception as e:
            logger.error(f"{os.path.basename(path)} | params (band={band}, pw={pw}, w={w}) failed: {e}")

    if best["perm"] is None:
        # Fallback an toàn nếu toàn bộ thử lỗi
        perm, cost, vis, tiles, feats, costs, prior = solve_one_image_with_params(
            path, w_base, band=6, prior_w=w_base["prior_w"], initial_piece=initial_piece, do_local_improve=True
        )
        best.update({"perm":perm,"cost":cost,"w":w_base,"band":6,"prior_w":w_base["prior_w"],
                     "vis":vis,"tiles":tiles,"feats":feats,"costs":costs,"prior":prior})

    logger.info(f"{os.path.basename(path)} | best_cost={best['cost']:.6f} | band={best['band']} | "
                f"prior_w={best['prior_w']} | w={best['w']}")
    return best

print("✅ Cell 9 ready.")
# Out:
# ✅ Cell 9 ready.

# %%
# ============================================================
# Cell 10 — UNSUPERVISED ONLINE LEARNING (TRAIN ONLY)
# ------------------------------------------------------------
# - Pseudo-label cạnh dương từ perm tốt nhất; âm = top ứng viên còn lại.
# - Hinge loss: max(0, m + w·f_pos - w·f_neg)
# - Projected GD + EMA smoothing.
# ============================================================

class AdaptiveCueWeights:
    def __init__(self, w0, bounds, cfg):
        self.w = dict(w0)   # alpha..lbp, prior_w (prior_w cập nhật nhẹ qua EMA)
        self.bounds = bounds
        self.cfg = cfg

    def _proj(self):
        for k, (lo, hi) in self.bounds.items():
            self.w[k] = float(np.clip(self.w[k], lo, hi))

    def _feat(self, feats, i, j, d, band):
        return edge_feature_vec(feats[i], feats[j], d, band)

    def update_with_pseudo(self, best, costs):
        """Cập nhật self.w (alpha..lbp) từ pseudo edges trong best perm."""
        perm = best["perm"]; feats = best["feats"]; band = self.cfg["band_for_learning"]
        if feats is None or perm is None:
            return

        # Duyệt positive edges theo grid (R, D)
        pos_edges = []
        for pos, p in enumerate(perm):
            r, c = divmod(pos, GRID_C)
            if c + 1 < GRID_C:
                pos_edges.append( (p, perm[pos+1], 'R') )
            if r + 1 < GRID_R:
                pos_edges.append( (p, perm[pos+GRID_C], 'D') )

        neg_per_pos = self.cfg["negatives_per_pos"]
        pairs = []
        for (i, j_true, d) in pos_edges:
            row = costs[d][i,:].copy()
            row[i] = np.inf
            cand = np.argsort(row).tolist()
            negs = [k for k in cand if k != j_true][:neg_per_pos]
            if not negs:
                continue
            f_pos = self._feat(feats, i, j_true, d, band)
            for j_neg in negs:
                f_neg = self._feat(feats, i, j_neg, d, band)
                pairs.append( (f_pos, f_neg) )
            if len(pairs) >= self.cfg["max_pairs_per_image"]:
                break

        if not pairs:
            return

        m  = self.cfg["margin"]
        lr = self.cfg["lr"]
        grad = {"alpha":0.0,"beta":0.0,"gamma":0.0,"ori":0.0,"lbp":0.0}
        count = 0

        for f_pos, f_neg in pairs:
            s_pos = (self.w["alpha"]*f_pos[0] + self.w["beta"]*f_pos[1] + self.w["gamma"]*f_pos[2] +
                     self.w["ori"]*f_pos[3]   + self.w["lbp"]*f_pos[4])
            s_neg = (self.w["alpha"]*f_neg[0] + self.w["beta"]*f_neg[1] + self.w["gamma"]*f_neg[2] +
                     self.w["ori"]*f_neg[3]   + self.w["lbp"]*f_neg[4])
            loss = m + s_pos - s_neg
            if loss > 0:
                grad["alpha"] += (f_pos[0] - f_neg[0])
                grad["beta"]  += (f_pos[1] - f_neg[1])
                grad["gamma"] += (f_pos[2] - f_neg[2])
                grad["ori"]   += (f_pos[3] - f_neg[3])
                grad["lbp"]   += (f_pos[4] - f_neg[4])
                count += 1

        if count > 0:
            scale = lr / count
            w_new = dict(self.w)
            for k in ["alpha","beta","gamma","ori","lbp"]:
                w_new[k] = self.w[k] - scale * grad[k]
                lo, hi = self.bounds[k]; w_new[k] = float(np.clip(w_new[k], lo, hi))
            # EMA smoothing
            ema = self.cfg["ema"]
            for k in ["alpha","beta","gamma","ori","lbp"]:
                self.w[k] = ema*self.w[k] + (1-ema)*w_new[k]
            self._proj()

    def get_w(self):
        return dict(self.w)

print("✅ Cell 10 ready.")
# Out:
# ✅ Cell 10 ready.

# %%
# ============================================================
# Cell 11 — TRAIN PIPELINE
# ------------------------------------------------------------
# - Mỗi ảnh train:
#   + (Nếu có) hint cho task1 -> cố định (0,0).
#   + Auto tuning (grid nhỏ, có giới hạn thời gian/lượt).
#   + Lưu ảnh đã ghép vào images/sloved/task{1,2}.
#   + Online learning: cập nhật w (alpha..lbp) từ pseudo-edges.
# - Cuối cùng: chọn band/prior_w toàn cục theo "mode" và FREEZE.
#   => Lưu model JSON: weights (alpha..lbp, prior_w), band, prior_w.
# ============================================================

def run_train_split(train_dir, sloved_dir, learner, hints_csv=None):
    os.makedirs(sloved_dir, exist_ok=True)
    files = list_images(train_dir)
    if not files:
        logger.warning(f"[TRAIN] Empty folder: {train_dir}")
    hints = load_hints_csv(hints_csv) if hints_csv else {}
    records = []  # lưu (band, prior_w) tốt nhất của từng ảnh

    for path in tqdm(files, desc=f"TRAIN on {os.path.basename(train_dir)}"):
        fname = os.path.basename(path)
        try:
            hint = hints.get(fname, None)
            w_base = learner.get_w()
            best = choose_best_for_image_with_tuning(path, w_base, initial_piece=hint)

            # Lưu ảnh đã ghép
            out_path = os.path.join(sloved_dir, fname)
            ok = cv2.imwrite(out_path, cv2.cvtColor(best["vis"], cv2.COLOR_RGB2BGR))
            if not ok:
                logger.warning(f"Failed to save solved image: {out_path}")

            logger.info(f"[TRAIN:{fname}] cost={best['cost']:.6f} | band={best['band']} | prior_w={best['prior_w']} | w={best['w']}")

            # Học online (chỉ alpha..lbp). prior_w cập nhật nhẹ qua EMA dưới đây
            learner.update_with_pseudo(best, best["costs"])

            # EMA nhẹ cho prior_w dựa vào best
            learner.w["prior_w"] = float(np.clip(
                LEARN_CFG["ema"] * learner.w["prior_w"] + (1-LEARN_CFG["ema"])*best["prior_w"],
                *W_BOUNDS["prior_w"]
            ))

            records.append((best["band"], best["prior_w"]))
        except Exception:
            logger.exception(f"[TRAIN:{fname}] error")
    return records

def mode_select(values):
    if not values:
        return None
    vals, cnts = np.unique(values, return_counts=True)
    return vals[np.argmax(cnts)]

# ---- Thực thi TRAIN ----
logger.info("===== TRAINING PHASE START =====")
learner = AdaptiveCueWeights(W_INIT, W_BOUNDS, LEARN_CFG)

rec_t1 = run_train_split(TRAIN_TASK1_DIR, SLOVED_TASK1, learner, hints_csv=HINTS_TRAIN1)
rec_t2 = run_train_split(TRAIN_TASK2_DIR, SLOVED_TASK2, learner, hints_csv=None)

all_bands    = [b for (b, pw) in (rec_t1 + rec_t2)]
all_prior_ws = [pw for (b, pw) in (rec_t1 + rec_t2)]
global_band    = int(mode_select(all_bands) if all_bands else 6)
global_prior_w = float(mode_select(all_prior_ws) if all_prior_ws else learner.get_w()["prior_w"])

TRAINED_MODEL = {
    "weights": learner.get_w(),      # alpha..lbp, prior_w (EMA)
    "band": int(global_band),        # band chọn theo mode
    "prior_w": float(global_prior_w) # prior_w chọn theo mode (ổn định)
}
with open(MODEL_PATH, "w", encoding="utf-8") as f:
    json.dump(TRAINED_MODEL, f, ensure_ascii=False, indent=2)
logger.info(f"[TRAIN DONE] Saved trained model to {MODEL_PATH}: {TRAINED_MODEL}")
print("✅ Cell 11 ready.")
# Out:
# 2025-10-29 04:54:56,076 | INFO | ===== TRAINING PHASE START =====
# 2025-10-29 04:54:56,078 | WARNING | Hint file not found (optional): /home/dammanhdungvn/learn_ml/project/output/task1_hints.csv
# TRAIN on task1:   0%|                                                                                          | 0/8 [00:00<?, ?it/s]/home/dammanhdungvn/learn_ml/venv/lib/python3.12/site-packages/skimage/feature/texture.py:385: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#   warnings.warn(
# 2025-10-29 04:55:00,390 | INFO | origin1.png | expansions=5000, frontier=10022
# 2025-10-29 04:55:00,773 | INFO | origin1.png | expansions=10000, frontier=13827
# 2025-10-29 04:55:01,064 | INFO | origin1.png | expansions=15000, frontier=15978
# 2025-10-29 04:55:01,306 | INFO | origin1.png | expansions=20000, frontier=14681
# 2025-10-29 04:55:01,500 | INFO | origin1.png | expansions=25000, frontier=10659
# 2025-10-29 04:55:01,593 | INFO | origin1.png | A* done | expansions=28526 | best_cost=53.122688
# 2025-10-29 04:55:05,973 | INFO | origin1.png | expansions=5000, frontier=10128
# 2025-10-29 04:55:06,301 | INFO | origin1.png | expansions=10000, frontier=13989
# 2025-10-29 04:55:06,595 | INFO | origin1.png | expansions=15000, frontier=16036
# 2025-10-29 04:55:06,822 | INFO | origin1.png | expansions=20000, frontier=14808
# 2025-10-29 04:55:06,993 | INFO | origin1.png | expansions=25000, frontier=10723
# 2025-10-29 04:55:07,083 | INFO | origin1.png | A* done | expansions=28156 | best_cost=52.615440
# 2025-10-29 04:55:11,107 | INFO | origin1.png | expansions=5000, frontier=9348
# 2025-10-29 04:55:11,410 | INFO | origin1.png | expansions=10000, frontier=13764
# 2025-10-29 04:55:11,665 | INFO | origin1.png | expansions=15000, frontier=15843
# 2025-10-29 04:55:11,874 | INFO | origin1.png | expansions=20000, frontier=14890
# 2025-10-29 04:55:12,061 | INFO | origin1.png | expansions=25000, frontier=10877
# 2025-10-29 04:55:12,177 | INFO | origin1.png | A* done | expansions=29573 | best_cost=52.682140
# 2025-10-29 04:55:16,878 | INFO | origin1.png | expansions=5000, frontier=9188
# 2025-10-29 04:55:17,225 | INFO | origin1.png | expansions=10000, frontier=13599
# 2025-10-29 04:55:17,485 | INFO | origin1.png | expansions=15000, frontier=15794
# 2025-10-29 04:55:17,766 | INFO | origin1.png | expansions=20000, frontier=14883
# 2025-10-29 04:55:17,966 | INFO | origin1.png | expansions=25000, frontier=10893
# 2025-10-29 04:55:18,084 | INFO | origin1.png | expansions=30000, frontier=5042
# 2025-10-29 04:55:18,085 | INFO | origin1.png | A* done | expansions=30014 | best_cost=54.874001
# 2025-10-29 04:55:22,060 | INFO | origin1.png | expansions=5000, frontier=10018
# 2025-10-29 04:55:22,353 | INFO | origin1.png | expansions=10000, frontier=13823
# 2025-10-29 04:55:22,598 | INFO | origin1.png | expansions=15000, frontier=15983
# 2025-10-29 04:55:22,818 | INFO | origin1.png | expansions=20000, frontier=14682
# 2025-10-29 04:55:22,991 | INFO | origin1.png | expansions=25000, frontier=10656
# 2025-10-29 04:55:23,080 | INFO | origin1.png | A* done | expansions=28522 | best_cost=53.114548
# 2025-10-29 04:55:27,052 | INFO | origin1.png | expansions=5000, frontier=9058
# 2025-10-29 04:55:27,375 | INFO | origin1.png | expansions=10000, frontier=13360
# 2025-10-29 04:55:27,647 | INFO | origin1.png | expansions=15000, frontier=15612
# 2025-10-29 04:55:27,856 | INFO | origin1.png | expansions=20000, frontier=14583
# 2025-10-29 04:55:28,043 | INFO | origin1.png | expansions=25000, frontier=10668
# 2025-10-29 04:55:28,182 | INFO | origin1.png | expansions=30000, frontier=4853
# 2025-10-29 04:55:28,200 | INFO | origin1.png | A* done | expansions=30751 | best_cost=52.836800
# 2025-10-29 04:55:32,196 | INFO | origin1.png | expansions=5000, frontier=9715
# 2025-10-29 04:55:32,524 | INFO | origin1.png | expansions=10000, frontier=13576
# 2025-10-29 04:55:32,862 | INFO | origin1.png | expansions=15000, frontier=15673
# 2025-10-29 04:55:33,094 | INFO | origin1.png | expansions=20000, frontier=14610
# 2025-10-29 04:55:33,269 | INFO | origin1.png | expansions=25000, frontier=10462
# 2025-10-29 04:55:33,397 | INFO | origin1.png | A* done | expansions=29707 | best_cost=54.501911
# 2025-10-29 04:55:37,421 | INFO | origin1.png | expansions=5000, frontier=8852
# 2025-10-29 04:55:37,750 | INFO | origin1.png | expansions=10000, frontier=13076
# 2025-10-29 04:55:38,031 | INFO | origin1.png | expansions=15000, frontier=15513
# 2025-10-29 04:55:38,281 | INFO | origin1.png | expansions=20000, frontier=14610
# 2025-10-29 04:55:38,465 | INFO | origin1.png | expansions=25000, frontier=10633
# 2025-10-29 04:55:38,584 | INFO | origin1.png | expansions=30000, frontier=4785
# 2025-10-29 04:55:38,613 | INFO | origin1.png | A* done | expansions=31081 | best_cost=53.656086
# 2025-10-29 04:55:42,645 | INFO | origin1.png | expansions=5000, frontier=9945
# 2025-10-29 04:55:42,970 | INFO | origin1.png | expansions=10000, frontier=13797
# 2025-10-29 04:55:43,256 | INFO | origin1.png | expansions=15000, frontier=15950
# 2025-10-29 04:55:43,470 | INFO | origin1.png | expansions=20000, frontier=14787
# 2025-10-29 04:55:43,671 | INFO | origin1.png | expansions=25000, frontier=10713
# 2025-10-29 04:55:43,771 | INFO | origin1.png | A* done | expansions=28727 | best_cost=54.838230
# 2025-10-29 04:55:48,516 | INFO | origin1.png | expansions=5000, frontier=10262
# 2025-10-29 04:55:48,868 | INFO | origin1.png | expansions=10000, frontier=14146
# 2025-10-29 04:55:49,171 | INFO | origin1.png | expansions=15000, frontier=16160
# 2025-10-29 04:55:49,414 | INFO | origin1.png | expansions=20000, frontier=14850
# 2025-10-29 04:55:49,633 | INFO | origin1.png | expansions=25000, frontier=10749
# 2025-10-29 04:55:49,754 | INFO | origin1.png | A* done | expansions=27554 | best_cost=50.423573
# 2025-10-29 04:55:53,940 | INFO | origin1.png | expansions=5000, frontier=10067
# 2025-10-29 04:55:54,308 | INFO | origin1.png | expansions=10000, frontier=13904
# 2025-10-29 04:55:54,738 | INFO | origin1.png | expansions=15000, frontier=15962
# 2025-10-29 04:55:55,172 | INFO | origin1.png | expansions=20000, frontier=14710
# 2025-10-29 04:55:55,382 | INFO | origin1.png | expansions=25000, frontier=10699
# 2025-10-29 04:55:55,521 | INFO | origin1.png | A* done | expansions=28314 | best_cost=54.370049
# 2025-10-29 04:56:00,430 | INFO | origin1.png | expansions=5000, frontier=8816
# 2025-10-29 04:56:00,872 | INFO | origin1.png | expansions=10000, frontier=13074
# 2025-10-29 04:56:01,216 | INFO | origin1.png | expansions=15000, frontier=15542
# 2025-10-29 04:56:01,468 | INFO | origin1.png | expansions=20000, frontier=14604
# 2025-10-29 04:56:01,678 | INFO | origin1.png | expansions=25000, frontier=10607
# 2025-10-29 04:56:01,853 | INFO | origin1.png | expansions=30000, frontier=4788
# 2025-10-29 04:56:01,879 | INFO | origin1.png | A* done | expansions=31199 | best_cost=55.462559
# 2025-10-29 04:56:06,008 | INFO | origin1.png | expansions=5000, frontier=9686
# 2025-10-29 04:56:06,368 | INFO | origin1.png | expansions=10000, frontier=13533
# 2025-10-29 04:56:06,782 | INFO | origin1.png | expansions=15000, frontier=15704
# 2025-10-29 04:56:07,078 | INFO | origin1.png | expansions=20000, frontier=14648
# 2025-10-29 04:56:07,287 | INFO | origin1.png | expansions=25000, frontier=10469
# 2025-10-29 04:56:07,449 | INFO | origin1.png | A* done | expansions=29764 | best_cost=53.113350
# 2025-10-29 04:56:07,500 | INFO | origin1.png | stop by time budget: 70s
# 2025-10-29 04:56:07,501 | INFO | origin1.png | best_cost=50.423580 | band=5 | prior_w=0.1 | w={'alpha': 1.0, 'beta': 0.35, 'gamma': 0.7000000000000001, 'ori': 0.1, 'lbp': 0.15000000000000002, 'prior_w': 0.1}
# 2025-10-29 04:56:07,526 | INFO | [TRAIN:origin1.png] cost=50.423580 | band=5 | prior_w=0.1 | w={'alpha': 1.0, 'beta': 0.35, 'gamma': 0.7000000000000001, 'ori': 0.1, 'lbp': 0.15000000000000002, 'prior_w': 0.1}
# TRAIN on task1:  12%|██████████▎                                                                       | 1/8 [01:11<08:22, 71.73s/it]
# 2025-10-29 04:56:12,266 | INFO | origin2.png | expansions=5000, frontier=10548
# 2025-10-29 04:56:12,604 | INFO | origin2.png | expansions=10000, frontier=14264
# 2025-10-29 04:56:12,883 | INFO | origin2.png | expansions=15000, frontier=15817
# 2025-10-29 04:56:13,097 | INFO | origin2.png | expansions=20000, frontier=14336
# 2025-10-29 04:56:13,287 | INFO | origin2.png | expansions=25000, frontier=10581
# 2025-10-29 04:56:13,317 | INFO | origin2.png | A* done | expansions=25661 | best_cost=48.474266
# 2025-10-29 04:56:17,516 | INFO | origin2.png | expansions=5000, frontier=10565
# 2025-10-29 04:56:17,902 | INFO | origin2.png | expansions=10000, frontier=14333
# 2025-10-29 04:56:18,212 | INFO | origin2.png | expansions=15000, frontier=15887
# 2025-10-29 04:56:18,455 | INFO | origin2.png | expansions=20000, frontier=14270
# 2025-10-29 04:56:18,632 | INFO | origin2.png | expansions=25000, frontier=10626
# 2025-10-29 04:56:18,647 | INFO | origin2.png | A* done | expansions=25430 | best_cost=47.998035
# 2025-10-29 04:56:23,483 | INFO | origin2.png | expansions=5000, frontier=10040
# 2025-10-29 04:56:23,867 | INFO | origin2.png | expansions=10000, frontier=14256
# 2025-10-29 04:56:24,183 | INFO | origin2.png | expansions=15000, frontier=16176
# 2025-10-29 04:56:24,433 | INFO | origin2.png | expansions=20000, frontier=14668
# 2025-10-29 04:56:24,625 | INFO | origin2.png | expansions=25000, frontier=10786
# 2025-10-29 04:56:24,679 | INFO | origin2.png | A* done | expansions=26657 | best_cost=48.562527
# 2025-10-29 04:56:29,089 | INFO | origin2.png | expansions=5000, frontier=9812
# 2025-10-29 04:56:29,390 | INFO | origin2.png | expansions=10000, frontier=14064
# 2025-10-29 04:56:29,628 | INFO | origin2.png | expansions=15000, frontier=16047
# 2025-10-29 04:56:29,835 | INFO | origin2.png | expansions=20000, frontier=14633
# 2025-10-29 04:56:29,998 | INFO | origin2.png | expansions=25000, frontier=10746
# 2025-10-29 04:56:30,072 | INFO | origin2.png | A* done | expansions=27346 | best_cost=50.753529
# 2025-10-29 04:56:34,041 | INFO | origin2.png | expansions=5000, frontier=10536
# 2025-10-29 04:56:34,325 | INFO | origin2.png | expansions=10000, frontier=14250
# 2025-10-29 04:56:34,597 | INFO | origin2.png | expansions=15000, frontier=15831
# 2025-10-29 04:56:34,815 | INFO | origin2.png | expansions=20000, frontier=14343
# 2025-10-29 04:56:34,964 | INFO | origin2.png | expansions=25000, frontier=10580
# 2025-10-29 04:56:34,985 | INFO | origin2.png | A* done | expansions=25681 | best_cost=48.465275
# 2025-10-29 04:56:39,473 | INFO | origin2.png | expansions=5000, frontier=10095
# 2025-10-29 04:56:39,807 | INFO | origin2.png | expansions=10000, frontier=14572
# 2025-10-29 04:56:40,101 | INFO | origin2.png | expansions=15000, frontier=16245
# 2025-10-29 04:56:40,342 | INFO | origin2.png | expansions=20000, frontier=14754
# 2025-10-29 04:56:40,495 | INFO | origin2.png | expansions=25000, frontier=10807
# 2025-10-29 04:56:40,575 | INFO | origin2.png | A* done | expansions=27509 | best_cost=47.973900
# 2025-10-29 04:56:44,846 | INFO | origin2.png | expansions=5000, frontier=10343
# 2025-10-29 04:56:45,227 | INFO | origin2.png | expansions=10000, frontier=14300
# 2025-10-29 04:56:45,492 | INFO | origin2.png | expansions=15000, frontier=15938
# 2025-10-29 04:56:45,723 | INFO | origin2.png | expansions=20000, frontier=14342
# 2025-10-29 04:56:45,921 | INFO | origin2.png | expansions=25000, frontier=10551
# 2025-10-29 04:56:45,968 | INFO | origin2.png | A* done | expansions=26353 | best_cost=49.172054
# 2025-10-29 04:56:50,354 | INFO | origin2.png | expansions=5000, frontier=9929
# 2025-10-29 04:56:50,701 | INFO | origin2.png | expansions=10000, frontier=14378
# 2025-10-29 04:56:50,972 | INFO | origin2.png | expansions=15000, frontier=16138
# 2025-10-29 04:56:51,229 | INFO | origin2.png | expansions=20000, frontier=14802
# 2025-10-29 04:56:51,422 | INFO | origin2.png | expansions=25000, frontier=10823
# 2025-10-29 04:56:51,511 | INFO | origin2.png | A* done | expansions=28110 | best_cost=48.811897
# 2025-10-29 04:56:56,235 | INFO | origin2.png | expansions=5000, frontier=10380
# 2025-10-29 04:56:56,536 | INFO | origin2.png | expansions=10000, frontier=14152
# 2025-10-29 04:56:56,862 | INFO | origin2.png | expansions=15000, frontier=15761
# 2025-10-29 04:56:57,113 | INFO | origin2.png | expansions=20000, frontier=14234
# 2025-10-29 04:56:57,309 | INFO | origin2.png | expansions=25000, frontier=10581
# 2025-10-29 04:56:57,340 | INFO | origin2.png | A* done | expansions=25927 | best_cost=50.218922
# 2025-10-29 04:57:02,179 | INFO | origin2.png | expansions=5000, frontier=10729
# 2025-10-29 04:57:02,504 | INFO | origin2.png | expansions=10000, frontier=14517
# 2025-10-29 04:57:02,766 | INFO | origin2.png | expansions=15000, frontier=16002
# 2025-10-29 04:57:02,990 | INFO | origin2.png | expansions=20000, frontier=14326
# 2025-10-29 04:57:03,179 | INFO | origin2.png | A* done | expansions=24889 | best_cost=45.807030
# 2025-10-29 04:57:07,328 | INFO | origin2.png | expansions=5000, frontier=10490
# 2025-10-29 04:57:07,647 | INFO | origin2.png | expansions=10000, frontier=14237
# 2025-10-29 04:57:07,889 | INFO | origin2.png | expansions=15000, frontier=15892
# 2025-10-29 04:57:08,119 | INFO | origin2.png | expansions=20000, frontier=14258
# 2025-10-29 04:57:08,300 | INFO | origin2.png | expansions=25000, frontier=10578
# 2025-10-29 04:57:08,323 | INFO | origin2.png | A* done | expansions=25599 | best_cost=49.781570
# 2025-10-29 04:57:12,385 | INFO | origin2.png | expansions=5000, frontier=9863
# 2025-10-29 04:57:12,742 | INFO | origin2.png | expansions=10000, frontier=14348
# 2025-10-29 04:57:12,999 | INFO | origin2.png | expansions=15000, frontier=16117
# 2025-10-29 04:57:13,230 | INFO | origin2.png | expansions=20000, frontier=14732
# 2025-10-29 04:57:13,394 | INFO | origin2.png | expansions=25000, frontier=10815
# 2025-10-29 04:57:13,478 | INFO | origin2.png | A* done | expansions=28362 | best_cost=50.604996
# 2025-10-29 04:57:17,545 | INFO | origin2.png | expansions=5000, frontier=10334
# 2025-10-29 04:57:17,838 | INFO | origin2.png | expansions=10000, frontier=14251
# 2025-10-29 04:57:18,095 | INFO | origin2.png | expansions=15000, frontier=15816
# 2025-10-29 04:57:18,311 | INFO | origin2.png | expansions=20000, frontier=14288
# 2025-10-29 04:57:18,480 | INFO | origin2.png | expansions=25000, frontier=10573
# 2025-10-29 04:57:18,529 | INFO | origin2.png | A* done | expansions=26340 | best_cost=47.802597
# 2025-10-29 04:57:18,572 | INFO | origin2.png | stop by time budget: 70s
# 2025-10-29 04:57:18,572 | INFO | origin2.png | best_cost=45.807026 | band=5 | prior_w=0.1 | w={'alpha': 0.9991041600704194, 'beta': 0.3498648738861084, 'gamma': 0.7000000017881395, 'ori': 0.10012049846351148, 'lbp': 0.15008317552506925, 'prior_w': 0.1}
# 2025-10-29 04:57:18,600 | INFO | [TRAIN:origin2.png] cost=45.807026 | band=5 | prior_w=0.1 | w={'alpha': 0.9991041600704194, 'beta': 0.3498648738861084, 'gamma': 0.7000000017881395, 'ori': 0.10012049846351148, 'lbp': 0.15008317552506925, 'prior_w': 0.1}
# TRAIN on task1:  25%|████████████████████▌                                                             | 2/8 [02:22<07:07, 71.32s/it]
# 2025-10-29 04:57:23,163 | INFO | origin3.png | expansions=5000, frontier=11336
# 2025-10-29 04:57:23,513 | INFO | origin3.png | expansions=10000, frontier=15255
# 2025-10-29 04:57:23,816 | INFO | origin3.png | expansions=15000, frontier=17464
# 2025-10-29 04:57:24,076 | INFO | origin3.png | expansions=20000, frontier=16274
# 2025-10-29 04:57:24,258 | INFO | origin3.png | expansions=25000, frontier=12473
# 2025-10-29 04:57:24,309 | INFO | origin3.png | A* done | expansions=26650 | best_cost=44.874218
# 2025-10-29 04:57:29,901 | INFO | origin3.png | expansions=5000, frontier=11420
# 2025-10-29 04:57:30,468 | INFO | origin3.png | expansions=10000, frontier=15361
# 2025-10-29 04:57:31,063 | INFO | origin3.png | expansions=15000, frontier=17577
# 2025-10-29 04:57:31,414 | INFO | origin3.png | expansions=20000, frontier=16284
# 2025-10-29 04:57:31,675 | INFO | origin3.png | expansions=25000, frontier=12484
# 2025-10-29 04:57:31,724 | INFO | origin3.png | A* done | expansions=26320 | best_cost=44.337669
# 2025-10-29 04:57:36,230 | INFO | origin3.png | expansions=5000, frontier=11270
# 2025-10-29 04:57:36,719 | INFO | origin3.png | expansions=10000, frontier=15047
# 2025-10-29 04:57:37,004 | INFO | origin3.png | expansions=15000, frontier=17421
# 2025-10-29 04:57:37,276 | INFO | origin3.png | expansions=20000, frontier=16191
# 2025-10-29 04:57:37,483 | INFO | origin3.png | expansions=25000, frontier=12260
# 2025-10-29 04:57:37,529 | INFO | origin3.png | A* done | expansions=26234 | best_cost=44.930908
# 2025-10-29 04:57:41,900 | INFO | origin3.png | expansions=5000, frontier=11030
# 2025-10-29 04:57:42,225 | INFO | origin3.png | expansions=10000, frontier=14842
# 2025-10-29 04:57:42,520 | INFO | origin3.png | expansions=15000, frontier=17302
# 2025-10-29 04:57:42,770 | INFO | origin3.png | expansions=20000, frontier=16111
# 2025-10-29 04:57:42,952 | INFO | origin3.png | expansions=25000, frontier=12146
# 2025-10-29 04:57:43,021 | INFO | origin3.png | A* done | expansions=26887 | best_cost=47.107838
# 2025-10-29 04:57:47,788 | INFO | origin3.png | expansions=5000, frontier=11342
# 2025-10-29 04:57:48,140 | INFO | origin3.png | expansions=10000, frontier=15296
# 2025-10-29 04:57:48,479 | INFO | origin3.png | expansions=15000, frontier=17504
# 2025-10-29 04:57:48,718 | INFO | origin3.png | expansions=20000, frontier=16268
# 2025-10-29 04:57:48,928 | INFO | origin3.png | expansions=25000, frontier=12453
# 2025-10-29 04:57:48,995 | INFO | origin3.png | A* done | expansions=26662 | best_cost=44.851151
# 2025-10-29 04:57:53,255 | INFO | origin3.png | expansions=5000, frontier=11465
# 2025-10-29 04:57:53,586 | INFO | origin3.png | expansions=10000, frontier=15304
# 2025-10-29 04:57:53,849 | INFO | origin3.png | expansions=15000, frontier=17642
# 2025-10-29 04:57:54,101 | INFO | origin3.png | expansions=20000, frontier=16448
# 2025-10-29 04:57:54,309 | INFO | origin3.png | expansions=25000, frontier=12285
# 2025-10-29 04:57:54,358 | INFO | origin3.png | A* done | expansions=26575 | best_cost=43.683826
# 2025-10-29 04:57:59,230 | INFO | origin3.png | expansions=5000, frontier=11535
# 2025-10-29 04:57:59,574 | INFO | origin3.png | expansions=10000, frontier=15472
# 2025-10-29 04:57:59,871 | INFO | origin3.png | expansions=15000, frontier=17653
# 2025-10-29 04:58:00,197 | INFO | origin3.png | expansions=20000, frontier=16452
# 2025-10-29 04:58:00,414 | INFO | origin3.png | expansions=25000, frontier=12495
# 2025-10-29 04:58:00,466 | INFO | origin3.png | A* done | expansions=26875 | best_cost=44.828110
# 2025-10-29 04:58:04,666 | INFO | origin3.png | expansions=5000, frontier=11273
# 2025-10-29 04:58:04,997 | INFO | origin3.png | expansions=10000, frontier=15135
# 2025-10-29 04:58:05,264 | INFO | origin3.png | expansions=15000, frontier=17605
# 2025-10-29 04:58:05,541 | INFO | origin3.png | expansions=20000, frontier=16351
# 2025-10-29 04:58:05,715 | INFO | origin3.png | expansions=25000, frontier=12299
# 2025-10-29 04:58:05,774 | INFO | origin3.png | A* done | expansions=27238 | best_cost=44.608696
# 2025-10-29 04:58:10,093 | INFO | origin3.png | expansions=5000, frontier=11200
# 2025-10-29 04:58:10,512 | INFO | origin3.png | expansions=10000, frontier=15204
# 2025-10-29 04:58:10,821 | INFO | origin3.png | expansions=15000, frontier=17414
# 2025-10-29 04:58:11,078 | INFO | origin3.png | expansions=20000, frontier=16184
# 2025-10-29 04:58:11,289 | INFO | origin3.png | expansions=25000, frontier=12364
# 2025-10-29 04:58:11,344 | INFO | origin3.png | A* done | expansions=26849 | best_cost=46.565609
# 2025-10-29 04:58:15,489 | INFO | origin3.png | expansions=5000, frontier=11595
# 2025-10-29 04:58:15,807 | INFO | origin3.png | expansions=10000, frontier=15573
# 2025-10-29 04:58:16,069 | INFO | origin3.png | expansions=15000, frontier=17639
# 2025-10-29 04:58:16,287 | INFO | origin3.png | expansions=20000, frontier=16367
# 2025-10-29 04:58:16,444 | INFO | origin3.png | expansions=25000, frontier=12554
# 2025-10-29 04:58:16,463 | INFO | origin3.png | A* done | expansions=25627 | best_cost=42.160728
# 2025-10-29 04:58:20,482 | INFO | origin3.png | expansions=5000, frontier=11314
# 2025-10-29 04:58:20,877 | INFO | origin3.png | expansions=10000, frontier=15339
# 2025-10-29 04:58:21,242 | INFO | origin3.png | expansions=15000, frontier=17580
# 2025-10-29 04:58:21,573 | INFO | origin3.png | expansions=20000, frontier=16269
# 2025-10-29 04:58:21,782 | INFO | origin3.png | expansions=25000, frontier=12395
# 2025-10-29 04:58:21,825 | INFO | origin3.png | A* done | expansions=26447 | best_cost=46.103130
# 2025-10-29 04:58:26,248 | INFO | origin3.png | expansions=5000, frontier=11165
# 2025-10-29 04:58:26,565 | INFO | origin3.png | expansions=10000, frontier=15062
# 2025-10-29 04:58:26,865 | INFO | origin3.png | expansions=15000, frontier=17591
# 2025-10-29 04:58:27,111 | INFO | origin3.png | expansions=20000, frontier=16343
# 2025-10-29 04:58:27,299 | INFO | origin3.png | expansions=25000, frontier=12235
# 2025-10-29 04:58:27,379 | INFO | origin3.png | A* done | expansions=27497 | best_cost=46.370949
# 2025-10-29 04:58:32,394 | INFO | origin3.png | expansions=5000, frontier=11530
# 2025-10-29 04:58:32,839 | INFO | origin3.png | expansions=10000, frontier=15562
# 2025-10-29 04:58:33,158 | INFO | origin3.png | expansions=15000, frontier=17714
# 2025-10-29 04:58:33,388 | INFO | origin3.png | expansions=20000, frontier=16486
# 2025-10-29 04:58:33,552 | INFO | origin3.png | expansions=25000, frontier=12469
# 2025-10-29 04:58:33,627 | INFO | origin3.png | A* done | expansions=26901 | best_cost=43.533371
# 2025-10-29 04:58:33,690 | INFO | origin3.png | stop by time budget: 70s
# 2025-10-29 04:58:33,693 | INFO | origin3.png | best_cost=42.160728 | band=5 | prior_w=0.1 | w={'alpha': 0.9979598823189736, 'beta': 0.3506995723247528, 'gamma': 0.7000000033080579, 'ori': 0.1003367506377399, 'lbp': 0.1503202197365463, 'prior_w': 0.1}
# 2025-10-29 04:58:33,714 | INFO | [TRAIN:origin3.png] cost=42.160728 | band=5 | prior_w=0.1 | w={'alpha': 0.9979598823189736, 'beta': 0.3506995723247528, 'gamma': 0.7000000033080579, 'ori': 0.1003367506377399, 'lbp': 0.1503202197365463, 'prior_w': 0.1}
# TRAIN on task1:  38%|██████████████████████████████▊                                                   | 3/8 [03:37<06:05, 73.08s/it]
# 2025-10-29 04:58:38,664 | INFO | origin4.png | expansions=5000, frontier=9264
# 2025-10-29 04:58:39,136 | INFO | origin4.png | expansions=10000, frontier=13679
# 2025-10-29 04:58:39,457 | INFO | origin4.png | expansions=15000, frontier=15770
# 2025-10-29 04:58:39,710 | INFO | origin4.png | expansions=20000, frontier=14719
# 2025-10-29 04:58:39,903 | INFO | origin4.png | expansions=25000, frontier=10826
# 2025-10-29 04:58:40,016 | INFO | origin4.png | A* done | expansions=29775 | best_cost=53.852772
# 2025-10-29 04:58:44,396 | INFO | origin4.png | expansions=5000, frontier=9395
# 2025-10-29 04:58:44,782 | INFO | origin4.png | expansions=10000, frontier=13738
# 2025-10-29 04:58:45,061 | INFO | origin4.png | expansions=15000, frontier=15789
# 2025-10-29 04:58:45,314 | INFO | origin4.png | expansions=20000, frontier=14736
# 2025-10-29 04:58:45,487 | INFO | origin4.png | expansions=25000, frontier=10808
# 2025-10-29 04:58:45,598 | INFO | origin4.png | A* done | expansions=29534 | best_cost=53.396427
# 2025-10-29 04:58:50,112 | INFO | origin4.png | expansions=5000, frontier=9477
# 2025-10-29 04:58:50,553 | INFO | origin4.png | expansions=10000, frontier=13914
# 2025-10-29 04:58:50,855 | INFO | origin4.png | expansions=15000, frontier=15748
# 2025-10-29 04:58:51,110 | INFO | origin4.png | expansions=20000, frontier=14608
# 2025-10-29 04:58:51,268 | INFO | origin4.png | expansions=25000, frontier=10764
# 2025-10-29 04:58:51,469 | INFO | origin4.png | A* done | expansions=29786 | best_cost=52.370129
# 2025-10-29 04:58:56,682 | INFO | origin4.png | expansions=5000, frontier=9326
# 2025-10-29 04:58:57,095 | INFO | origin4.png | expansions=10000, frontier=13765
# 2025-10-29 04:58:57,411 | INFO | origin4.png | expansions=15000, frontier=15658
# 2025-10-29 04:58:57,658 | INFO | origin4.png | expansions=20000, frontier=14584
# 2025-10-29 04:58:57,846 | INFO | origin4.png | expansions=25000, frontier=10732
# 2025-10-29 04:58:57,980 | INFO | origin4.png | expansions=30000, frontier=5305
# 2025-10-29 04:58:57,986 | INFO | origin4.png | A* done | expansions=30229 | best_cost=54.560806
# 2025-10-29 04:59:02,951 | INFO | origin4.png | expansions=5000, frontier=9254
# 2025-10-29 04:59:04,063 | INFO | origin4.png | expansions=10000, frontier=13665
# 2025-10-29 04:59:04,381 | INFO | origin4.png | expansions=15000, frontier=15776
# 2025-10-29 04:59:04,618 | INFO | origin4.png | expansions=20000, frontier=14732
# 2025-10-29 04:59:04,816 | INFO | origin4.png | expansions=25000, frontier=10817
# 2025-10-29 04:59:04,961 | INFO | origin4.png | A* done | expansions=29778 | best_cost=53.843441
# 2025-10-29 04:59:09,803 | INFO | origin4.png | expansions=5000, frontier=9375
# 2025-10-29 04:59:10,152 | INFO | origin4.png | expansions=10000, frontier=13939
# 2025-10-29 04:59:10,506 | INFO | origin4.png | expansions=15000, frontier=15829
# 2025-10-29 04:59:10,741 | INFO | origin4.png | expansions=20000, frontier=14600
# 2025-10-29 04:59:10,921 | INFO | origin4.png | expansions=25000, frontier=10690
# 2025-10-29 04:59:11,039 | INFO | origin4.png | expansions=30000, frontier=5238
# 2025-10-29 04:59:11,064 | INFO | origin4.png | A* done | expansions=31179 | best_cost=52.957550
# 2025-10-29 04:59:15,554 | INFO | origin4.png | expansions=5000, frontier=9208
# 2025-10-29 04:59:15,883 | INFO | origin4.png | expansions=10000, frontier=13655
# 2025-10-29 04:59:16,170 | INFO | origin4.png | expansions=15000, frontier=15711
# 2025-10-29 04:59:16,405 | INFO | origin4.png | expansions=20000, frontier=14565
# 2025-10-29 04:59:16,621 | INFO | origin4.png | expansions=25000, frontier=10628
# 2025-10-29 04:59:16,752 | INFO | origin4.png | expansions=30000, frontier=5105
# 2025-10-29 04:59:16,777 | INFO | origin4.png | A* done | expansions=31126 | best_cost=55.768532
# 2025-10-29 04:59:21,164 | INFO | origin4.png | expansions=5000, frontier=9132
# 2025-10-29 04:59:21,519 | INFO | origin4.png | expansions=10000, frontier=13802
# 2025-10-29 04:59:21,786 | INFO | origin4.png | expansions=15000, frontier=15755
# 2025-10-29 04:59:22,024 | INFO | origin4.png | expansions=20000, frontier=14572
# 2025-10-29 04:59:22,193 | INFO | origin4.png | expansions=25000, frontier=10646
# 2025-10-29 04:59:22,306 | INFO | origin4.png | expansions=30000, frontier=5142
# 2025-10-29 04:59:22,332 | INFO | origin4.png | A* done | expansions=31420 | best_cost=53.665901
# 2025-10-29 04:59:26,660 | INFO | origin4.png | expansions=5000, frontier=9208
# 2025-10-29 04:59:27,018 | INFO | origin4.png | expansions=10000, frontier=13615
# 2025-10-29 04:59:27,300 | INFO | origin4.png | expansions=15000, frontier=15765
# 2025-10-29 04:59:27,607 | INFO | origin4.png | expansions=20000, frontier=14725
# 2025-10-29 04:59:27,797 | INFO | origin4.png | expansions=25000, frontier=10769
# 2025-10-29 04:59:27,916 | INFO | origin4.png | A* done | expansions=29951 | best_cost=55.618797
# 2025-10-29 04:59:32,224 | INFO | origin4.png | expansions=5000, frontier=9613
# 2025-10-29 04:59:32,561 | INFO | origin4.png | expansions=10000, frontier=13914
# 2025-10-29 04:59:32,864 | INFO | origin4.png | expansions=15000, frontier=15866
# 2025-10-29 04:59:33,110 | INFO | origin4.png | expansions=20000, frontier=14762
# 2025-10-29 04:59:33,283 | INFO | origin4.png | expansions=25000, frontier=10864
# 2025-10-29 04:59:33,391 | INFO | origin4.png | A* done | expansions=29053 | best_cost=51.205750
# 2025-10-29 04:59:38,158 | INFO | origin4.png | expansions=5000, frontier=9318
# 2025-10-29 04:59:38,535 | INFO | origin4.png | expansions=10000, frontier=13724
# 2025-10-29 04:59:38,793 | INFO | origin4.png | expansions=15000, frontier=15781
# 2025-10-29 04:59:39,027 | INFO | origin4.png | expansions=20000, frontier=14733
# 2025-10-29 04:59:39,202 | INFO | origin4.png | expansions=25000, frontier=10785
# 2025-10-29 04:59:39,305 | INFO | origin4.png | A* done | expansions=29697 | best_cost=55.203484
# 2025-10-29 04:59:43,855 | INFO | origin4.png | expansions=5000, frontier=9120
# 2025-10-29 04:59:44,214 | INFO | origin4.png | expansions=10000, frontier=13735
# 2025-10-29 04:59:44,496 | INFO | origin4.png | expansions=15000, frontier=15718
# 2025-10-29 04:59:44,715 | INFO | origin4.png | expansions=20000, frontier=14533
# 2025-10-29 04:59:44,902 | INFO | origin4.png | expansions=25000, frontier=10593
# 2025-10-29 04:59:45,015 | INFO | origin4.png | expansions=30000, frontier=5132
# 2025-10-29 04:59:45,043 | INFO | origin4.png | A* done | expansions=31518 | best_cost=55.526546
# 2025-10-29 04:59:45,079 | INFO | origin4.png | stop by time budget: 70s
# 2025-10-29 04:59:45,080 | INFO | origin4.png | best_cost=51.205746 | band=5 | prior_w=0.1 | w={'alpha': 0.9960619735270739, 'beta': 0.3498873415350914, 'gamma': 0.7000000045999885, 'ori': 0.10221055336054415, 'lbp': 0.15025535055007788, 'prior_w': 0.1}
# 2025-10-29 04:59:45,095 | INFO | [TRAIN:origin4.png] cost=51.205746 | band=5 | prior_w=0.1 | w={'alpha': 0.9960619735270739, 'beta': 0.3498873415350914, 'gamma': 0.7000000045999885, 'ori': 0.10221055336054415, 'lbp': 0.15025535055007788, 'prior_w': 0.1}
# TRAIN on task1:  50%|█████████████████████████████████████████                                         | 4/8 [04:49<04:49, 72.39s/it]
# 2025-10-29 04:59:49,731 | INFO | origin5.png | expansions=5000, frontier=10810
# 2025-10-29 04:59:50,162 | INFO | origin5.png | expansions=10000, frontier=14328
# 2025-10-29 04:59:50,615 | INFO | origin5.png | expansions=15000, frontier=16731
# 2025-10-29 04:59:50,862 | INFO | origin5.png | expansions=20000, frontier=15712
# 2025-10-29 04:59:51,060 | INFO | origin5.png | expansions=25000, frontier=11615
# 2025-10-29 04:59:51,125 | INFO | origin5.png | A* done | expansions=26815 | best_cost=49.212650
# 2025-10-29 04:59:55,555 | INFO | origin5.png | expansions=5000, frontier=10930
# 2025-10-29 04:59:56,032 | INFO | origin5.png | expansions=10000, frontier=14500
# 2025-10-29 04:59:56,363 | INFO | origin5.png | expansions=15000, frontier=16805
# 2025-10-29 04:59:56,617 | INFO | origin5.png | expansions=20000, frontier=15730
# 2025-10-29 04:59:56,819 | INFO | origin5.png | expansions=25000, frontier=11607
# 2025-10-29 04:59:56,860 | INFO | origin5.png | A* done | expansions=26377 | best_cost=48.554516
# 2025-10-29 05:00:01,596 | INFO | origin5.png | expansions=5000, frontier=10968
# 2025-10-29 05:00:01,943 | INFO | origin5.png | expansions=10000, frontier=14705
# 2025-10-29 05:00:02,319 | INFO | origin5.png | expansions=15000, frontier=16876
# 2025-10-29 05:00:02,577 | INFO | origin5.png | expansions=20000, frontier=15503
# 2025-10-29 05:00:02,799 | INFO | origin5.png | expansions=25000, frontier=11485
# 2025-10-29 05:00:02,827 | INFO | origin5.png | A* done | expansions=25685 | best_cost=45.607750
# 2025-10-29 05:00:08,473 | INFO | origin5.png | expansions=5000, frontier=10785
# 2025-10-29 05:00:08,838 | INFO | origin5.png | expansions=10000, frontier=14515
# 2025-10-29 05:00:09,862 | INFO | origin5.png | expansions=15000, frontier=16773
# 2025-10-29 05:00:10,114 | INFO | origin5.png | expansions=20000, frontier=15406
# 2025-10-29 05:00:10,319 | INFO | origin5.png | expansions=25000, frontier=11419
# 2025-10-29 05:00:10,370 | INFO | origin5.png | A* done | expansions=26235 | best_cost=47.799129
# 2025-10-29 05:00:15,510 | INFO | origin5.png | expansions=5000, frontier=10811
# 2025-10-29 05:00:15,843 | INFO | origin5.png | expansions=10000, frontier=14335
# 2025-10-29 05:00:16,188 | INFO | origin5.png | expansions=15000, frontier=16739
# 2025-10-29 05:00:16,439 | INFO | origin5.png | expansions=20000, frontier=15716
# 2025-10-29 05:00:16,607 | INFO | origin5.png | expansions=25000, frontier=11610
# 2025-10-29 05:00:16,661 | INFO | origin5.png | A* done | expansions=26817 | best_cost=49.204033
# 2025-10-29 05:00:21,162 | INFO | origin5.png | expansions=5000, frontier=10685
# 2025-10-29 05:00:21,517 | INFO | origin5.png | expansions=10000, frontier=14564
# 2025-10-29 05:00:21,811 | INFO | origin5.png | expansions=15000, frontier=16659
# 2025-10-29 05:00:22,036 | INFO | origin5.png | expansions=20000, frontier=15498
# 2025-10-29 05:00:22,201 | INFO | origin5.png | expansions=25000, frontier=11517
# 2025-10-29 05:00:22,340 | INFO | origin5.png | A* done | expansions=29771 | best_cost=47.968666
# 2025-10-29 05:00:26,784 | INFO | origin5.png | expansions=5000, frontier=10738
# 2025-10-29 05:00:27,122 | INFO | origin5.png | expansions=10000, frontier=14376
# 2025-10-29 05:00:27,414 | INFO | origin5.png | expansions=15000, frontier=16592
# 2025-10-29 05:00:27,676 | INFO | origin5.png | expansions=20000, frontier=15566
# 2025-10-29 05:00:27,853 | INFO | origin5.png | expansions=25000, frontier=11525
# 2025-10-29 05:00:27,978 | INFO | origin5.png | expansions=30000, frontier=5837
# 2025-10-29 05:00:27,987 | INFO | origin5.png | A* done | expansions=30348 | best_cost=52.547806
# 2025-10-29 05:00:32,618 | INFO | origin5.png | expansions=5000, frontier=10451
# 2025-10-29 05:00:32,997 | INFO | origin5.png | expansions=10000, frontier=14268
# 2025-10-29 05:00:33,280 | INFO | origin5.png | expansions=15000, frontier=16563
# 2025-10-29 05:00:33,583 | INFO | origin5.png | expansions=20000, frontier=15380
# 2025-10-29 05:00:33,777 | INFO | origin5.png | expansions=25000, frontier=11430
# 2025-10-29 05:00:33,940 | INFO | origin5.png | expansions=30000, frontier=5654
# 2025-10-29 05:00:33,951 | INFO | origin5.png | A* done | expansions=30361 | best_cost=49.000374
# 2025-10-29 05:00:38,235 | INFO | origin5.png | expansions=5000, frontier=10751
# 2025-10-29 05:00:38,539 | INFO | origin5.png | expansions=10000, frontier=14270
# 2025-10-29 05:00:38,875 | INFO | origin5.png | expansions=15000, frontier=16767
# 2025-10-29 05:00:39,111 | INFO | origin5.png | expansions=20000, frontier=15716
# 2025-10-29 05:00:39,292 | INFO | origin5.png | expansions=25000, frontier=11532
# 2025-10-29 05:00:39,347 | INFO | origin5.png | A* done | expansions=26954 | best_cost=50.827782
# 2025-10-29 05:00:44,371 | INFO | origin5.png | expansions=5000, frontier=11122
# 2025-10-29 05:00:44,773 | INFO | origin5.png | expansions=10000, frontier=14676
# 2025-10-29 05:00:45,058 | INFO | origin5.png | expansions=15000, frontier=16967
# 2025-10-29 05:00:45,284 | INFO | origin5.png | expansions=20000, frontier=15786
# 2025-10-29 05:00:45,461 | INFO | origin5.png | expansions=25000, frontier=11689
# 2025-10-29 05:00:45,485 | INFO | origin5.png | A* done | expansions=25799 | best_cost=46.363136
# 2025-10-29 05:00:49,974 | INFO | origin5.png | expansions=5000, frontier=10851
# 2025-10-29 05:00:50,382 | INFO | origin5.png | expansions=10000, frontier=14396
# 2025-10-29 05:00:50,735 | INFO | origin5.png | expansions=15000, frontier=16813
# 2025-10-29 05:00:51,023 | INFO | origin5.png | expansions=20000, frontier=15719
# 2025-10-29 05:00:51,215 | INFO | origin5.png | expansions=25000, frontier=11535
# 2025-10-29 05:00:51,260 | INFO | origin5.png | A* done | expansions=26512 | best_cost=50.260151
# 2025-10-29 05:00:56,036 | INFO | origin5.png | expansions=5000, frontier=10437
# 2025-10-29 05:00:56,409 | INFO | origin5.png | expansions=10000, frontier=14197
# 2025-10-29 05:00:56,770 | INFO | origin5.png | expansions=15000, frontier=16569
# 2025-10-29 05:00:57,020 | INFO | origin5.png | expansions=20000, frontier=15382
# 2025-10-29 05:00:57,219 | INFO | origin5.png | expansions=25000, frontier=11410
# 2025-10-29 05:00:57,361 | INFO | origin5.png | expansions=30000, frontier=5663
# 2025-10-29 05:00:57,370 | INFO | origin5.png | A* done | expansions=30501 | best_cost=50.730549
# 2025-10-29 05:00:57,411 | INFO | origin5.png | stop by time budget: 70s
# 2025-10-29 05:00:57,412 | INFO | origin5.png | best_cost=45.607750 | band=5 | prior_w=0.0 | w={'alpha': 0.9946932791091503, 'beta': 0.3999239581173658, 'gamma': 0.8000000056981296, 'ori': 0.10295218499171548, 'lbp': 0.15035581562723033, 'prior_w': 0.1}
# 2025-10-29 05:00:57,427 | INFO | [TRAIN:origin5.png] cost=45.607750 | band=5 | prior_w=0.0 | w={'alpha': 0.9946932791091503, 'beta': 0.3999239581173658, 'gamma': 0.8000000056981296, 'ori': 0.10295218499171548, 'lbp': 0.15035581562723033, 'prior_w': 0.1}
# TRAIN on task1:  62%|███████████████████████████████████████████████████▎                              | 5/8 [06:01<03:37, 72.38s/it]
# 2025-10-29 05:01:02,039 | INFO | origin6.png | expansions=5000, frontier=10236
# 2025-10-29 05:01:02,431 | INFO | origin6.png | expansions=10000, frontier=14327
# 2025-10-29 05:01:02,734 | INFO | origin6.png | expansions=15000, frontier=16149
# 2025-10-29 05:01:02,990 | INFO | origin6.png | expansions=20000, frontier=15134
# 2025-10-29 05:01:03,190 | INFO | origin6.png | expansions=25000, frontier=11412
# 2025-10-29 05:01:03,310 | INFO | origin6.png | A* done | expansions=29526 | best_cost=57.052299
# 2025-10-29 05:01:08,070 | INFO | origin6.png | expansions=5000, frontier=10417
# 2025-10-29 05:01:08,508 | INFO | origin6.png | expansions=10000, frontier=14470
# 2025-10-29 05:01:08,876 | INFO | origin6.png | expansions=15000, frontier=16196
# 2025-10-29 05:01:09,189 | INFO | origin6.png | expansions=20000, frontier=15174
# 2025-10-29 05:01:09,394 | INFO | origin6.png | expansions=25000, frontier=11414
# 2025-10-29 05:01:09,521 | INFO | origin6.png | A* done | expansions=29243 | best_cost=56.541920
# 2025-10-29 05:01:14,678 | INFO | origin6.png | expansions=5000, frontier=10231
# 2025-10-29 05:01:15,627 | INFO | origin6.png | expansions=10000, frontier=14346
# 2025-10-29 05:01:15,924 | INFO | origin6.png | expansions=15000, frontier=16159
# 2025-10-29 05:01:16,181 | INFO | origin6.png | expansions=20000, frontier=15127
# 2025-10-29 05:01:16,400 | INFO | origin6.png | expansions=25000, frontier=11393
# 2025-10-29 05:01:16,504 | INFO | origin6.png | A* done | expansions=27924 | best_cost=50.438538
# 2025-10-29 05:01:20,855 | INFO | origin6.png | expansions=5000, frontier=10110
# 2025-10-29 05:01:21,199 | INFO | origin6.png | expansions=10000, frontier=14209
# 2025-10-29 05:01:21,548 | INFO | origin6.png | expansions=15000, frontier=16098
# 2025-10-29 05:01:21,781 | INFO | origin6.png | expansions=20000, frontier=15099
# 2025-10-29 05:01:21,947 | INFO | origin6.png | expansions=25000, frontier=11354
# 2025-10-29 05:01:22,046 | INFO | origin6.png | A* done | expansions=28500 | best_cost=52.626667
# 2025-10-29 05:01:26,544 | INFO | origin6.png | expansions=5000, frontier=10233
# 2025-10-29 05:01:26,982 | INFO | origin6.png | expansions=10000, frontier=14323
# 2025-10-29 05:01:27,304 | INFO | origin6.png | expansions=15000, frontier=16142
# 2025-10-29 05:01:27,578 | INFO | origin6.png | expansions=20000, frontier=15133
# 2025-10-29 05:01:27,826 | INFO | origin6.png | expansions=25000, frontier=11408
# 2025-10-29 05:01:27,970 | INFO | origin6.png | A* done | expansions=29525 | best_cost=57.040428
# 2025-10-29 05:01:33,016 | INFO | origin6.png | expansions=5000, frontier=9886
# 2025-10-29 05:01:33,441 | INFO | origin6.png | expansions=10000, frontier=13885
# 2025-10-29 05:01:33,748 | INFO | origin6.png | expansions=15000, frontier=16024
# 2025-10-29 05:01:33,992 | INFO | origin6.png | expansions=20000, frontier=15235
# 2025-10-29 05:01:34,182 | INFO | origin6.png | expansions=25000, frontier=11444
# 2025-10-29 05:01:34,319 | INFO | origin6.png | A* done | expansions=29968 | best_cost=51.507591
# 2025-10-29 05:01:38,898 | INFO | origin6.png | expansions=5000, frontier=10019
# 2025-10-29 05:01:39,270 | INFO | origin6.png | expansions=10000, frontier=13910
# 2025-10-29 05:01:39,587 | INFO | origin6.png | expansions=15000, frontier=16072
# 2025-10-29 05:01:39,837 | INFO | origin6.png | expansions=20000, frontier=15388
# 2025-10-29 05:01:40,022 | INFO | origin6.png | expansions=25000, frontier=11558
# 2025-10-29 05:01:40,162 | INFO | origin6.png | expansions=30000, frontier=5554
# 2025-10-29 05:01:40,180 | INFO | origin6.png | A* done | expansions=30964 | best_cost=59.369705
# 2025-10-29 05:01:44,688 | INFO | origin6.png | expansions=5000, frontier=9648
# 2025-10-29 05:01:45,187 | INFO | origin6.png | expansions=10000, frontier=13730
# 2025-10-29 05:01:45,525 | INFO | origin6.png | expansions=15000, frontier=16029
# 2025-10-29 05:01:45,795 | INFO | origin6.png | expansions=20000, frontier=15198
# 2025-10-29 05:01:46,020 | INFO | origin6.png | expansions=25000, frontier=11373
# 2025-10-29 05:01:46,161 | INFO | origin6.png | expansions=30000, frontier=5553
# 2025-10-29 05:01:46,171 | INFO | origin6.png | A* done | expansions=30385 | best_cost=52.315228
# 2025-10-29 05:01:51,347 | INFO | origin6.png | expansions=5000, frontier=10237
# 2025-10-29 05:01:51,797 | INFO | origin6.png | expansions=10000, frontier=14315
# 2025-10-29 05:01:52,108 | INFO | origin6.png | expansions=15000, frontier=16102
# 2025-10-29 05:01:52,373 | INFO | origin6.png | expansions=20000, frontier=15112
# 2025-10-29 05:01:52,557 | INFO | origin6.png | expansions=25000, frontier=11381
# 2025-10-29 05:01:52,683 | INFO | origin6.png | A* done | expansions=29665 | best_cost=58.787281
# 2025-10-29 05:01:57,299 | INFO | origin6.png | expansions=5000, frontier=10575
# 2025-10-29 05:01:57,657 | INFO | origin6.png | expansions=10000, frontier=14627
# 2025-10-29 05:01:57,970 | INFO | origin6.png | expansions=15000, frontier=16281
# 2025-10-29 05:01:58,227 | INFO | origin6.png | expansions=20000, frontier=15219
# 2025-10-29 05:01:58,400 | INFO | origin6.png | expansions=25000, frontier=11458
# 2025-10-29 05:01:58,506 | INFO | origin6.png | A* done | expansions=28728 | best_cost=54.353790
# 2025-10-29 05:02:03,647 | INFO | origin6.png | expansions=5000, frontier=10398
# 2025-10-29 05:02:04,011 | INFO | origin6.png | expansions=10000, frontier=14428
# 2025-10-29 05:02:04,347 | INFO | origin6.png | expansions=15000, frontier=16143
# 2025-10-29 05:02:04,626 | INFO | origin6.png | expansions=20000, frontier=15164
# 2025-10-29 05:02:04,842 | INFO | origin6.png | expansions=25000, frontier=11471
# 2025-10-29 05:02:04,986 | INFO | origin6.png | A* done | expansions=29392 | best_cost=58.346012
# 2025-10-29 05:02:09,560 | INFO | origin6.png | expansions=5000, frontier=9595
# 2025-10-29 05:02:09,927 | INFO | origin6.png | expansions=10000, frontier=13638
# 2025-10-29 05:02:10,294 | INFO | origin6.png | expansions=15000, frontier=16000
# 2025-10-29 05:02:10,572 | INFO | origin6.png | expansions=20000, frontier=15245
# 2025-10-29 05:02:10,776 | INFO | origin6.png | expansions=25000, frontier=11411
# 2025-10-29 05:02:10,905 | INFO | origin6.png | expansions=30000, frontier=5504
# 2025-10-29 05:02:10,918 | INFO | origin6.png | A* done | expansions=30543 | best_cost=54.143211
# 2025-10-29 05:02:10,961 | INFO | origin6.png | stop by time budget: 70s
# 2025-10-29 05:02:10,962 | INFO | origin6.png | best_cost=50.438538 | band=5 | prior_w=0.0 | w={'alpha': 0.9915335475062208, 'beta': 0.3998631092651784, 'gamma': 0.8000000066315496, 'ori': 0.10353543093718728, 'lbp': 0.1504085997515372, 'prior_w': 0.085}
# 2025-10-29 05:02:10,977 | INFO | [TRAIN:origin6.png] cost=50.438538 | band=5 | prior_w=0.0 | w={'alpha': 0.9915335475062208, 'beta': 0.3998631092651784, 'gamma': 0.8000000066315496, 'ori': 0.10353543093718728, 'lbp': 0.1504085997515372, 'prior_w': 0.085}
# TRAIN on task1:  75%|█████████████████████████████████████████████████████████████▌                    | 6/8 [07:15<02:25, 72.78s/it]
# 2025-10-29 05:02:15,889 | INFO | origin7.png | expansions=5000, frontier=10316
# 2025-10-29 05:02:16,272 | INFO | origin7.png | expansions=10000, frontier=13773
# 2025-10-29 05:02:16,627 | INFO | origin7.png | expansions=15000, frontier=17588
# 2025-10-29 05:02:16,906 | INFO | origin7.png | expansions=20000, frontier=16789
# 2025-10-29 05:02:17,117 | INFO | origin7.png | expansions=25000, frontier=12228
# 2025-10-29 05:02:17,317 | INFO | origin7.png | expansions=30000, frontier=5144
# 2025-10-29 05:02:17,367 | INFO | origin7.png | A* done | expansions=32752 | best_cost=71.793671
# 2025-10-29 05:02:22,865 | INFO | origin7.png | expansions=5000, frontier=10352
# 2025-10-29 05:02:23,317 | INFO | origin7.png | expansions=10000, frontier=13803
# 2025-10-29 05:02:23,802 | INFO | origin7.png | expansions=15000, frontier=17640
# 2025-10-29 05:02:24,114 | INFO | origin7.png | expansions=20000, frontier=16822
# 2025-10-29 05:02:24,339 | INFO | origin7.png | expansions=25000, frontier=12194
# 2025-10-29 05:02:24,509 | INFO | origin7.png | expansions=30000, frontier=5204
# 2025-10-29 05:02:24,563 | INFO | origin7.png | A* done | expansions=32752 | best_cost=71.504761
# 2025-10-29 05:02:29,970 | INFO | origin7.png | expansions=5000, frontier=10335
# 2025-10-29 05:02:30,389 | INFO | origin7.png | expansions=10000, frontier=13734
# 2025-10-29 05:02:30,757 | INFO | origin7.png | expansions=15000, frontier=17587
# 2025-10-29 05:02:31,061 | INFO | origin7.png | expansions=20000, frontier=16831
# 2025-10-29 05:02:31,297 | INFO | origin7.png | expansions=25000, frontier=12216
# 2025-10-29 05:02:31,464 | INFO | origin7.png | expansions=30000, frontier=5220
# 2025-10-29 05:02:31,528 | INFO | origin7.png | A* done | expansions=32752 | best_cost=73.114365
# 2025-10-29 05:02:36,279 | INFO | origin7.png | expansions=5000, frontier=10326
# 2025-10-29 05:02:36,750 | INFO | origin7.png | expansions=10000, frontier=13728
# 2025-10-29 05:02:37,097 | INFO | origin7.png | expansions=15000, frontier=17570
# 2025-10-29 05:02:37,387 | INFO | origin7.png | expansions=20000, frontier=16815
# 2025-10-29 05:02:37,603 | INFO | origin7.png | expansions=25000, frontier=12212
# 2025-10-29 05:02:37,772 | INFO | origin7.png | expansions=30000, frontier=5206
# 2025-10-29 05:02:37,831 | INFO | origin7.png | A* done | expansions=32752 | best_cost=75.304764
# 2025-10-29 05:02:43,025 | INFO | origin7.png | expansions=5000, frontier=10324
# 2025-10-29 05:02:43,522 | INFO | origin7.png | expansions=10000, frontier=13774
# 2025-10-29 05:02:43,950 | INFO | origin7.png | expansions=15000, frontier=17587
# 2025-10-29 05:02:44,253 | INFO | origin7.png | expansions=20000, frontier=16790
# 2025-10-29 05:02:44,476 | INFO | origin7.png | expansions=25000, frontier=12218
# 2025-10-29 05:02:44,648 | INFO | origin7.png | expansions=30000, frontier=5145
# 2025-10-29 05:02:44,708 | INFO | origin7.png | A* done | expansions=32752 | best_cost=71.784073
# 2025-10-29 05:02:50,385 | INFO | origin7.png | expansions=5000, frontier=10128
# 2025-10-29 05:02:50,961 | INFO | origin7.png | expansions=10000, frontier=13603
# 2025-10-29 05:02:51,503 | INFO | origin7.png | expansions=15000, frontier=17332
# 2025-10-29 05:02:52,037 | INFO | origin7.png | expansions=20000, frontier=16483
# 2025-10-29 05:02:52,276 | INFO | origin7.png | expansions=25000, frontier=12109
# 2025-10-29 05:02:52,454 | INFO | origin7.png | expansions=30000, frontier=5400
# 2025-10-29 05:02:52,531 | INFO | origin7.png | A* done | expansions=32752 | best_cost=70.813148
# 2025-10-29 05:02:58,634 | INFO | origin7.png | expansions=5000, frontier=10103
# 2025-10-29 05:02:59,106 | INFO | origin7.png | expansions=10000, frontier=13611
# 2025-10-29 05:02:59,489 | INFO | origin7.png | expansions=15000, frontier=17404
# 2025-10-29 05:02:59,835 | INFO | origin7.png | expansions=20000, frontier=16510
# 2025-10-29 05:03:00,051 | INFO | origin7.png | expansions=25000, frontier=12093
# 2025-10-29 05:03:00,209 | INFO | origin7.png | expansions=30000, frontier=5398
# 2025-10-29 05:03:00,264 | INFO | origin7.png | A* done | expansions=32752 | best_cost=71.606125
# 2025-10-29 05:03:05,064 | INFO | origin7.png | expansions=5000, frontier=9990
# 2025-10-29 05:03:05,600 | INFO | origin7.png | expansions=10000, frontier=13604
# 2025-10-29 05:03:05,985 | INFO | origin7.png | expansions=15000, frontier=17236
# 2025-10-29 05:03:06,305 | INFO | origin7.png | expansions=20000, frontier=16506
# 2025-10-29 05:03:06,565 | INFO | origin7.png | expansions=25000, frontier=12125
# 2025-10-29 05:03:06,752 | INFO | origin7.png | expansions=30000, frontier=5441
# 2025-10-29 05:03:06,807 | INFO | origin7.png | A* done | expansions=32752 | best_cost=71.341782
# 2025-10-29 05:03:12,028 | INFO | origin7.png | expansions=5000, frontier=10339
# 2025-10-29 05:03:12,424 | INFO | origin7.png | expansions=10000, frontier=13804
# 2025-10-29 05:03:12,734 | INFO | origin7.png | expansions=15000, frontier=17613
# 2025-10-29 05:03:12,990 | INFO | origin7.png | expansions=20000, frontier=16799
# ...
# TRAIN on task2:  75%|████████████████████████████████████████████████████████████▊                    | 6/8 [41:59<18:58, 569.31s/it]
# 2025-10-29 05:46:46,037 | INFO | origin7.png | expansions=5000, frontier=10320
# 2025-10-29 05:46:46,370 | INFO | origin7.png | expansions=10000, frontier=13776
# 2025-10-29 05:46:46,645 | INFO | origin7.png | expansions=15000, frontier=17583
# 2025-10-29 05:46:46,928 | INFO | origin7.png | expansions=20000, frontier=16780
# 2025-10-29 05:46:47,094 | INFO | origin7.png | expansions=25000, frontier=12218
# 2025-10-29 05:46:47,220 | INFO | origin7.png | expansions=30000, frontier=5144
# 2025-10-29 05:46:47,271 | INFO | origin7.png | A* done | expansions=32752 | best_cost=71.184227
# 2025-10-29 05:46:51,280 | INFO | origin7.png | expansions=5000, frontier=10356
# 2025-10-29 05:46:51,610 | INFO | origin7.png | expansions=10000, frontier=13813
# 2025-10-29 05:46:51,927 | INFO | origin7.png | expansions=15000, frontier=17624
# 2025-10-29 05:46:52,157 | INFO | origin7.png | expansions=20000, frontier=16804
# 2025-10-29 05:46:52,332 | INFO | origin7.png | expansions=25000, frontier=12206
# 2025-10-29 05:46:52,469 | INFO | origin7.png | expansions=30000, frontier=5219
# 2025-10-29 05:46:52,515 | INFO | origin7.png | A* done | expansions=32752 | best_cost=70.898537
# 2025-10-29 05:46:56,544 | INFO | origin7.png | expansions=5000, frontier=10326
# 2025-10-29 05:46:56,876 | INFO | origin7.png | expansions=10000, frontier=13742
# 2025-10-29 05:46:57,164 | INFO | origin7.png | expansions=15000, frontier=17584
# 2025-10-29 05:46:57,436 | INFO | origin7.png | expansions=20000, frontier=16824
# 2025-10-29 05:46:57,614 | INFO | origin7.png | expansions=25000, frontier=12206
# 2025-10-29 05:46:57,740 | INFO | origin7.png | expansions=30000, frontier=5197
# 2025-10-29 05:46:57,789 | INFO | origin7.png | A* done | expansions=32752 | best_cost=72.504921
# 2025-10-29 05:47:02,590 | INFO | origin7.png | expansions=5000, frontier=10322
# 2025-10-29 05:47:02,906 | INFO | origin7.png | expansions=10000, frontier=13740
# 2025-10-29 05:47:03,193 | INFO | origin7.png | expansions=15000, frontier=17590
# 2025-10-29 05:47:03,443 | INFO | origin7.png | expansions=20000, frontier=16828
# 2025-10-29 05:47:03,627 | INFO | origin7.png | expansions=25000, frontier=12212
# 2025-10-29 05:47:03,773 | INFO | origin7.png | expansions=30000, frontier=5198
# 2025-10-29 05:47:03,831 | INFO | origin7.png | A* done | expansions=32752 | best_cost=74.695320
# 2025-10-29 05:47:07,818 | INFO | origin7.png | expansions=5000, frontier=10323
# 2025-10-29 05:47:08,212 | INFO | origin7.png | expansions=10000, frontier=13768
# 2025-10-29 05:47:08,515 | INFO | origin7.png | expansions=15000, frontier=17589
# 2025-10-29 05:47:08,744 | INFO | origin7.png | expansions=20000, frontier=16802
# 2025-10-29 05:47:08,933 | INFO | origin7.png | expansions=25000, frontier=12212
# 2025-10-29 05:47:09,064 | INFO | origin7.png | expansions=30000, frontier=5141
# 2025-10-29 05:47:09,120 | INFO | origin7.png | A* done | expansions=32752 | best_cost=71.174629
# 2025-10-29 05:47:13,033 | INFO | origin7.png | expansions=5000, frontier=10133
# 2025-10-29 05:47:13,377 | INFO | origin7.png | expansions=10000, frontier=13620
# 2025-10-29 05:47:13,709 | INFO | origin7.png | expansions=15000, frontier=17381
# 2025-10-29 05:47:13,974 | INFO | origin7.png | expansions=20000, frontier=16525
# 2025-10-29 05:47:14,165 | INFO | origin7.png | expansions=25000, frontier=12119
# 2025-10-29 05:47:14,292 | INFO | origin7.png | expansions=30000, frontier=5408
# 2025-10-29 05:47:14,349 | INFO | origin7.png | A* done | expansions=32752 | best_cost=70.204819
# 2025-10-29 05:47:18,302 | INFO | origin7.png | expansions=5000, frontier=10106
# 2025-10-29 05:47:18,644 | INFO | origin7.png | expansions=10000, frontier=13611
# 2025-10-29 05:47:18,935 | INFO | origin7.png | expansions=15000, frontier=17405
# 2025-10-29 05:47:19,155 | INFO | origin7.png | expansions=20000, frontier=16514
# 2025-10-29 05:47:19,380 | INFO | origin7.png | expansions=25000, frontier=12101
# 2025-10-29 05:47:19,524 | INFO | origin7.png | expansions=30000, frontier=5405
# 2025-10-29 05:47:19,579 | INFO | origin7.png | A* done | expansions=32752 | best_cost=70.997795
# 2025-10-29 05:47:23,650 | INFO | origin7.png | expansions=5000, frontier=9985
# 2025-10-29 05:47:23,979 | INFO | origin7.png | expansions=10000, frontier=13605
# 2025-10-29 05:47:24,292 | INFO | origin7.png | expansions=15000, frontier=17232
# 2025-10-29 05:47:24,531 | INFO | origin7.png | expansions=20000, frontier=16504
# 2025-10-29 05:47:24,723 | INFO | origin7.png | expansions=25000, frontier=12141
# 2025-10-29 05:47:24,860 | INFO | origin7.png | expansions=30000, frontier=5443
# 2025-10-29 05:47:24,913 | INFO | origin7.png | A* done | expansions=32752 | best_cost=70.729637
# 2025-10-29 05:47:28,935 | INFO | origin7.png | expansions=5000, frontier=10334
# 2025-10-29 05:47:29,303 | INFO | origin7.png | expansions=10000, frontier=13810
# 2025-10-29 05:47:29,590 | INFO | origin7.png | expansions=15000, frontier=17587
# 2025-10-29 05:47:29,848 | INFO | origin7.png | expansions=20000, frontier=16783
# 2025-10-29 05:47:30,065 | INFO | origin7.png | expansions=25000, frontier=12164
# 2025-10-29 05:47:30,218 | INFO | origin7.png | expansions=30000, frontier=5241
# 2025-10-29 05:47:30,290 | INFO | origin7.png | A* done | expansions=32752 | best_cost=73.132820
# 2025-10-29 05:47:35,548 | INFO | origin7.png | expansions=5000, frontier=10345
# 2025-10-29 05:47:36,012 | INFO | origin7.png | expansions=10000, frontier=13800
# 2025-10-29 05:47:36,356 | INFO | origin7.png | expansions=15000, frontier=17622
# 2025-10-29 05:47:36,587 | INFO | origin7.png | expansions=20000, frontier=16808
# 2025-10-29 05:47:36,758 | INFO | origin7.png | expansions=25000, frontier=12198
# 2025-10-29 05:47:36,896 | INFO | origin7.png | expansions=30000, frontier=5200
# 2025-10-29 05:47:36,940 | INFO | origin7.png | A* done | expansions=32752 | best_cost=68.707138
# 2025-10-29 05:47:41,020 | INFO | origin7.png | expansions=5000, frontier=10373
# 2025-10-29 05:47:41,331 | INFO | origin7.png | expansions=10000, frontier=13826
# 2025-10-29 05:47:41,667 | INFO | origin7.png | expansions=15000, frontier=17646
# 2025-10-29 05:47:41,898 | INFO | origin7.png | expansions=20000, frontier=16863
# 2025-10-29 05:47:42,056 | INFO | origin7.png | expansions=25000, frontier=12235
# 2025-10-29 05:47:42,175 | INFO | origin7.png | expansions=30000, frontier=5207
# 2025-10-29 05:47:42,230 | INFO | origin7.png | A* done | expansions=32752 | best_cost=73.283325
# 2025-10-29 05:47:46,689 | INFO | origin7.png | expansions=5000, frontier=10042
# 2025-10-29 05:47:47,101 | INFO | origin7.png | expansions=10000, frontier=13574
# 2025-10-29 05:47:47,400 | INFO | origin7.png | expansions=15000, frontier=17190
# 2025-10-29 05:47:47,671 | INFO | origin7.png | expansions=20000, frontier=16472
# 2025-10-29 05:47:47,835 | INFO | origin7.png | expansions=25000, frontier=12071
# 2025-10-29 05:47:47,965 | INFO | origin7.png | expansions=30000, frontier=5397
# 2025-10-29 05:47:48,008 | INFO | origin7.png | A* done | expansions=32752 | best_cost=72.866447
# 2025-10-29 05:47:52,182 | INFO | origin7.png | expansions=5000, frontier=10024
# 2025-10-29 05:47:52,594 | INFO | origin7.png | expansions=10000, frontier=13539
# 2025-10-29 05:47:52,933 | INFO | origin7.png | expansions=15000, frontier=17286
# 2025-10-29 05:47:53,206 | INFO | origin7.png | expansions=20000, frontier=16504
# 2025-10-29 05:47:53,408 | INFO | origin7.png | expansions=25000, frontier=12213
# 2025-10-29 05:47:53,547 | INFO | origin7.png | expansions=30000, frontier=5415
# 2025-10-29 05:47:53,594 | INFO | origin7.png | A* done | expansions=32752 | best_cost=69.338715
# 2025-10-29 05:47:53,633 | INFO | origin7.png | stop by time budget: 70s
# 2025-10-29 05:47:53,634 | INFO | origin7.png | best_cost=68.707146 | band=5 | prior_w=0.1 | w={'alpha': 0.9805423163645542, 'beta': 0.3432121760621319, 'gamma': 0.7000000106958192, 'ori': 0.107993267138107, 'lbp': 0.15088492429967565, 'prior_w': 0.06468838793016601}
# 2025-10-29 05:47:53,645 | INFO | [TRAIN:origin7.png] cost=68.707146 | band=5 | prior_w=0.1 | w={'alpha': 0.9805423163645542, 'beta': 0.3432121760621319, 'gamma': 0.7000000106958192, 'ori': 0.107993267138107, 'lbp': 0.15088492429967565, 'prior_w': 0.06468838793016601}
# TRAIN on task2:  88%|██████████████████████████████████████████████████████████████████████▉          | 7/8 [43:10<06:46, 406.70s/it]
# 2025-10-29 05:47:58,211 | INFO | origin8.png | expansions=5000, frontier=11879
# 2025-10-29 05:47:58,538 | INFO | origin8.png | expansions=10000, frontier=16024
# 2025-10-29 05:47:58,797 | INFO | origin8.png | expansions=15000, frontier=17769
# 2025-10-29 05:47:59,039 | INFO | origin8.png | expansions=20000, frontier=16071
# 2025-10-29 05:47:59,277 | INFO | origin8.png | expansions=25000, frontier=12029
# 2025-10-29 05:47:59,317 | INFO | origin8.png | A* done | expansions=26187 | best_cost=41.793369
# 2025-10-29 05:48:03,843 | INFO | origin8.png | expansions=5000, frontier=12005
# 2025-10-29 05:48:04,235 | INFO | origin8.png | expansions=10000, frontier=16122
# 2025-10-29 05:48:04,554 | INFO | origin8.png | expansions=15000, frontier=17978
# 2025-10-29 05:48:04,798 | INFO | origin8.png | expansions=20000, frontier=16130
# 2025-10-29 05:48:04,967 | INFO | origin8.png | expansions=25000, frontier=12100
# 2025-10-29 05:48:04,996 | INFO | origin8.png | A* done | expansions=25994 | best_cost=41.405010
# 2025-10-29 05:48:09,912 | INFO | origin8.png | expansions=5000, frontier=11894
# 2025-10-29 05:48:10,286 | INFO | origin8.png | expansions=10000, frontier=16034
# 2025-10-29 05:48:10,590 | INFO | origin8.png | expansions=15000, frontier=17900
# 2025-10-29 05:48:10,839 | INFO | origin8.png | expansions=20000, frontier=16086
# 2025-10-29 05:48:10,998 | INFO | origin8.png | expansions=25000, frontier=12059
# 2025-10-29 05:48:11,034 | INFO | origin8.png | A* done | expansions=26213 | best_cost=42.554691
# 2025-10-29 05:48:15,318 | INFO | origin8.png | expansions=5000, frontier=11674
# 2025-10-29 05:48:15,676 | INFO | origin8.png | expansions=10000, frontier=15819
# 2025-10-29 05:48:15,961 | INFO | origin8.png | expansions=15000, frontier=17704
# 2025-10-29 05:48:16,185 | INFO | origin8.png | expansions=20000, frontier=15995
# 2025-10-29 05:48:16,373 | INFO | origin8.png | expansions=25000, frontier=11922
# 2025-10-29 05:48:16,450 | INFO | origin8.png | A* done | expansions=26805 | best_cost=44.743927
# 2025-10-29 05:48:20,930 | INFO | origin8.png | expansions=5000, frontier=11875
# 2025-10-29 05:48:21,326 | INFO | origin8.png | expansions=10000, frontier=16012
# 2025-10-29 05:48:21,671 | INFO | origin8.png | expansions=15000, frontier=17761
# 2025-10-29 05:48:21,886 | INFO | origin8.png | expansions=20000, frontier=16068
# 2025-10-29 05:48:22,056 | INFO | origin8.png | expansions=25000, frontier=12027
# 2025-10-29 05:48:22,097 | INFO | origin8.png | A* done | expansions=26193 | best_cost=41.782604
# 2025-10-29 05:48:26,420 | INFO | origin8.png | expansions=5000, frontier=11886
# 2025-10-29 05:48:26,777 | INFO | origin8.png | expansions=10000, frontier=15890
# 2025-10-29 05:48:27,045 | INFO | origin8.png | expansions=15000, frontier=17625
# 2025-10-29 05:48:27,257 | INFO | origin8.png | expansions=20000, frontier=15914
# 2025-10-29 05:48:27,433 | INFO | origin8.png | expansions=25000, frontier=11950
# 2025-10-29 05:48:27,546 | INFO | origin8.png | A* done | expansions=29441 | best_cost=43.927406
# 2025-10-29 05:48:32,221 | INFO | origin8.png | expansions=5000, frontier=11854
# 2025-10-29 05:48:32,567 | INFO | origin8.png | expansions=10000, frontier=15957
# 2025-10-29 05:48:32,855 | INFO | origin8.png | expansions=15000, frontier=17512
# 2025-10-29 05:48:33,169 | INFO | origin8.png | expansions=20000, frontier=15876
# 2025-10-29 05:48:33,365 | INFO | origin8.png | expansions=25000, frontier=11996
# 2025-10-29 05:48:33,480 | INFO | origin8.png | A* done | expansions=29588 | best_cost=44.654934
# 2025-10-29 05:48:37,647 | INFO | origin8.png | expansions=5000, frontier=11520
# 2025-10-29 05:48:37,955 | INFO | origin8.png | expansions=10000, frontier=15606
# 2025-10-29 05:48:38,347 | INFO | origin8.png | expansions=15000, frontier=17485
# 2025-10-29 05:48:38,638 | INFO | origin8.png | expansions=20000, frontier=15939
# 2025-10-29 05:48:39,527 | INFO | origin8.png | expansions=25000, frontier=11860
# 2025-10-29 05:48:39,598 | INFO | origin8.png | A* done | expansions=27808 | best_cost=43.023132
# 2025-10-29 05:48:44,101 | INFO | origin8.png | expansions=5000, frontier=11767
# 2025-10-29 05:48:44,449 | INFO | origin8.png | expansions=10000, frontier=15908
# 2025-10-29 05:48:44,733 | INFO | origin8.png | expansions=15000, frontier=17805
# 2025-10-29 05:48:44,947 | INFO | origin8.png | expansions=20000, frontier=16043
# 2025-10-29 05:48:45,169 | INFO | origin8.png | expansions=25000, frontier=11998
# 2025-10-29 05:48:45,293 | INFO | origin8.png | A* done | expansions=26578 | best_cost=43.649044
# 2025-10-29 05:48:49,863 | INFO | origin8.png | expansions=5000, frontier=12186
# 2025-10-29 05:48:50,186 | INFO | origin8.png | expansions=10000, frontier=16306
# 2025-10-29 05:48:50,442 | INFO | origin8.png | expansions=15000, frontier=18152
# 2025-10-29 05:48:50,652 | INFO | origin8.png | expansions=20000, frontier=16236
# 2025-10-29 05:48:50,806 | INFO | origin8.png | expansions=25000, frontier=12289
# 2025-10-29 05:48:50,821 | INFO | origin8.png | A* done | expansions=25325 | best_cost=39.215775
# 2025-10-29 05:48:54,726 | INFO | origin8.png | expansions=5000, frontier=11905
# 2025-10-29 05:48:55,055 | INFO | origin8.png | expansions=10000, frontier=16098
# 2025-10-29 05:48:55,328 | INFO | origin8.png | expansions=15000, frontier=17892
# 2025-10-29 05:48:55,544 | INFO | origin8.png | expansions=20000, frontier=16039
# 2025-10-29 05:48:55,727 | INFO | origin8.png | expansions=25000, frontier=12026
# 2025-10-29 05:48:55,770 | INFO | origin8.png | A* done | expansions=26341 | best_cost=43.326256
# 2025-10-29 05:48:59,693 | INFO | origin8.png | expansions=5000, frontier=11405
# 2025-10-29 05:49:00,010 | INFO | origin8.png | expansions=10000, frontier=15489
# 2025-10-29 05:49:00,292 | INFO | origin8.png | expansions=15000, frontier=17379
# 2025-10-29 05:49:00,523 | INFO | origin8.png | expansions=20000, frontier=15845
# 2025-10-29 05:49:00,697 | INFO | origin8.png | expansions=25000, frontier=11765
# 2025-10-29 05:49:00,782 | INFO | origin8.png | A* done | expansions=28236 | best_cost=44.946182
# 2025-10-29 05:49:04,722 | INFO | origin8.png | expansions=5000, frontier=11665
# 2025-10-29 05:49:05,126 | INFO | origin8.png | expansions=10000, frontier=15832
# 2025-10-29 05:49:05,375 | INFO | origin8.png | expansions=15000, frontier=17578
# 2025-10-29 05:49:05,576 | INFO | origin8.png | expansions=20000, frontier=15994
# 2025-10-29 05:49:05,747 | INFO | origin8.png | expansions=25000, frontier=12049
# 2025-10-29 05:49:05,820 | INFO | origin8.png | A* done | expansions=27372 | best_cost=41.541264
# 2025-10-29 05:49:05,858 | INFO | origin8.png | stop by time budget: 70s
# 2025-10-29 05:49:05,859 | INFO | origin8.png | best_cost=39.215771 | band=5 | prior_w=0.1 | w={'alpha': 0.9800860972982759, 'beta': 0.34302722602371893, 'gamma': 0.7000000108795857, 'ori': 0.10801593744298604, 'lbp': 0.15088702723094294, 'prior_w': 0.06998512974064111}
# 2025-10-29 05:49:05,875 | INFO | [TRAIN:origin8.png] cost=39.215771 | band=5 | prior_w=0.1 | w={'alpha': 0.9800860972982759, 'beta': 0.34302722602371893, 'gamma': 0.7000000108795857, 'ori': 0.10801593744298604, 'lbp': 0.15088702723094294, 'prior_w': 0.06998512974064111}
# TRAIN on task2: 100%|█████████████████████████████████████████████████████████████████████████████████| 8/8 [44:23<00:00, 332.89s/it]
# 2025-10-29 05:49:06,184 | INFO | [TRAIN DONE] Saved trained model to /home/dammanhdungvn/learn_ml/project/output/trained_model.json: {'weights': {'alpha': 0.9794236618295111, 'beta': 0.34002558500460633, 'gamma': 0.8000000110357872, 'ori': 0.10807164054125219, 'lbp': 0.10092364767692683, 'prior_w': 0.07448736027954495}, 'band': 5, 'prior_w': 0.1}
# ✅ Cell 11 ready.

# %%
# ============================================================
# Cell 12 — INFERENCE: PUBLIC TEST (NO FINE-TUNE, NO LEARNING)
# ------------------------------------------------------------
# - Đọc model JSON (đã freeze) -> w, band, prior_w cố định.
# - Giải các PNG trong images/test (không tách task).
# - Hỗ trợ hint CSV (nếu có), mặc định None.
# - Xuất output/public_output.csv theo schema chấm.
# ============================================================

def solve_dir_fixed_params(test_dir, out_dir, out_csv, hints_csv=None, model_json=MODEL_PATH):
    try:
        require_dir(test_dir, create=False)
    except Exception:
        logger.error(f"[INFER] Test dir not found, skip: {test_dir}")
        return pd.DataFrame([])

    os.makedirs(out_dir, exist_ok=True)
    files = list_images(test_dir)
    if not files:
        logger.warning(f"[INFER] No PNG found in: {test_dir}")

    # Load model (đã freeze)
    with open(model_json, "r", encoding="utf-8") as f:
        mdl = json.load(f)
    w       = mdl["weights"]
    band    = int(mdl["band"])
    prior_w = float(mdl["prior_w"])
    hints = load_hints_csv(hints_csv) if hints_csv else {}

    rows = []
    for path in tqdm(files, desc=f"INFER on {os.path.basename(test_dir)}"):
        fname = os.path.basename(path)
        try:
            initial_piece = hints.get(fname, None)
            perm, cost, vis, tiles, feats, costs, prior = solve_one_image_with_params(
                path, w, band, prior_w, initial_piece=initial_piece, do_local_improve=True
            )
            cv2.imwrite(os.path.join(out_dir, fname), cv2.cvtColor(vis, cv2.COLOR_RGB2BGR))
            rows.append([fname] + perm)
            logger.info(f"[INFER:{fname}] cost={cost:.6f}")
        except Exception:
            logger.exception(f"[INFER:{fname}] error")

    cols = ["image_filename"] + [f"piece_at_{r}_{c}" for r in range(GRID_R) for c in range(GRID_C)]
    df = pd.DataFrame(rows, columns=cols)
    df.sort_values("image_filename", inplace=True)
    df.to_csv(out_csv, index=False, encoding="utf-8")
    logger.info(f"[INFER] Wrote {out_csv} with {len(df)} rows.")
    return df

logger.info("===== INFERENCE: PUBLIC TEST =====")
df_public = solve_dir_fixed_params(
    TEST_PUBLIC_DIR, SLOVED_PUBLIC, PUBLIC_CSV,
    hints_csv=HINTS_PUBLIC, model_json=MODEL_PATH
)
print("✅ Cell 12 ready.")
# Out:
# 2025-10-29 05:55:14,260 | INFO | ===== INFERENCE: PUBLIC TEST =====
# 2025-10-29 05:55:14,262 | ERROR | [INFER] Test dir not found, skip: /home/dammanhdungvn/learn_ml/project/images/test
# ✅ Cell 12 ready.

# %%
# ============================================================
# Cell 13 — INFERENCE: PRIVATE TEST (NO FINE-TUNE, NO LEARNING)
# ------------------------------------------------------------
# - Nếu thư mục private_test chưa mở khoá -> log và bỏ qua.
# - Nếu có HINTS_PRIVATE thì đọc, không thì None.
# - Xuất output/private_output.csv theo schema.
# ============================================================

logger.info("===== INFERENCE: PRIVATE TEST =====")
try:
    require_dir(PRIVATE_TEST_DIR, create=False)  # có thể chưa mở khoá
    df_private = solve_dir_fixed_params(
        PRIVATE_TEST_DIR, SLOVED_PRIVATE, PRIVATE_CSV,
        hints_csv=HINTS_PRIVATE, model_json=MODEL_PATH
    )
except Exception:
    logger.warning(f"[INFER] Private test dir missing or locked. Skip. Path={PRIVATE_TEST_DIR}")
print("✅ Cell 13 ready.")
# Out:
# 2025-10-29 05:55:08,448 | INFO | ===== INFERENCE: PRIVATE TEST =====
# 2025-10-29 05:55:08,450 | WARNING | Hint file not found (optional): /home/dammanhdungvn/learn_ml/project/output/private_task1_hints.csv
# INFER on private_test:   0%|                                                                                   | 0/1 [00:00<?, ?it/s]
# 2025-10-29 05:55:12,755 | INFO | origin6.png | expansions=5000, frontier=10406
# 2025-10-29 05:55:13,118 | INFO | origin6.png | expansions=10000, frontier=14476
# 2025-10-29 05:55:13,469 | INFO | origin6.png | expansions=15000, frontier=16181
# 2025-10-29 05:55:13,725 | INFO | origin6.png | expansions=20000, frontier=15165
# 2025-10-29 05:55:13,918 | INFO | origin6.png | expansions=25000, frontier=11412
# 2025-10-29 05:55:14,040 | INFO | origin6.png | A* done | expansions=29292 | best_cost=55.973598
# 2025-10-29 05:55:14,089 | INFO | [INFER:origin6.png] cost=55.973595
# INFER on private_test: 100%|███████████████████████████████████████████████████████████████████████████| 1/1 [00:05<00:00,  5.64s/it]
# 2025-10-29 05:55:14,094 | INFO | [INFER] Wrote /home/dammanhdungvn/learn_ml/project/output/private_output.csv with 1 rows.
# ✅ Cell 13 ready.

# %%
# ============================================================
# Cell 14 — PACKAGE SUBMISSION
# ------------------------------------------------------------
# - Đóng gói public_output.csv + (private_output.csv nếu có)
#   + Notebook (.ipynb) + trained_model.json vào submission.zip.
# ============================================================

NOTEBOOK_FILENAME = "solver_voai_task2_train_freeze_infer.ipynb"  # ← sửa đúng tên file notebook của bạn

with zipfile.ZipFile(SUBMISSION, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
    for p in [PUBLIC_CSV, PRIVATE_CSV, MODEL_PATH]:
        if os.path.isfile(p):
            zf.write(p, arcname=os.path.basename(p))
    nb_local = os.path.join(os.getcwd(), NOTEBOOK_FILENAME)
    nb_alt   = os.path.join(os.path.join(BASE_DIR, "code"), NOTEBOOK_FILENAME)
    nb_path  = nb_local if os.path.isfile(nb_local) else nb_alt
    if os.path.isfile(nb_path):
        zf.write(nb_path, arcname=NOTEBOOK_FILENAME)

logger.info(f"Created {SUBMISSION}.")
print("✅ DONE: Training → Freeze → Public/Private inference completed.")
# Out:
# 2025-10-29 05:52:58,699 | INFO | Created /home/dammanhdungvn/learn_ml/project/output/submission.zip.
# ✅ DONE: Training → Freeze → Public/Private inference completed.
